# %%
from json_profile_generator import generate_profile
profile = generate_profile("data/raw/part1.json.trimmed.json") # передаем путь в json

# %%
prompt = """

Следующий профиль в формате json задает собой реляционную структуру в БД. Твоя задача дать названия бизнес-сущностям и всем полям.

Профиль:

""" + str(profile) + """
Ответ выдай строго чистым JSON без комментариев ни до не после. Структура json ответа строго такая:

{
  "entity_names": {
    "[<entity_path>]": "<new_entity_name>"
  },
  "entity_descriptions": {
    "[<entity_path>]": "<one-sentence-what-this-entity-represents>"
  },
  "column_names": {
    "[<entity_path>]::[<column_path>]": "<new_column_name>"
  },
  "column_descriptions": {
    "[<entity_path>]::[<column_path>]": "<short-meaning-and-units-if-any>"
  },
  "notes": "<optional-freeform-notes-about-naming-decisions>"
}


"""

# %%
import json 
from validate_rename_patch import validate_rename_patch


# patch - это  ответ от LLM - Просим нам LLM правильно назвать сущности и поля бизнесово.

with open("rename1.json", "r", encoding="utf-8") as f:
    patch = json.load(f)

result = validate_rename_patch(profile, patch)  # критик - он уже сам скажет какие ошибки в ответе и если все норм, то SUCCESS
print(result)
# Out:
# SUCCESS

# %%
from final_profile import build_final_profile_from_files

final_prof = build_final_profile_from_files("profile.json", "rename1.json")
# дальше можете сериализовать, генерировать DDL/DBML, и пр.
# import json; print(json.dumps(final_prof, ensure_ascii=False, indent=2))

# %%
final_prof
# Out:
# {'version': '1.0',
#  'root': '__root__',
#  'entities': [{'name': 'IndividualEntrepreneur',
#    'path': [],
#    'depth': 0,
#    'parent': None,
#    'primary_key': ['rec_id'],
#    'columns': [{'name': 'CitizenshipTypeCode',
#      'path': ['citizenship_kind'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['1', '2', '1'],
#      'types_seen': ['string'],
#      'description': 'Код типа гражданства (например, гражданин РФ, иностранец и т.п.).'},
#     {'name': 'CitizenshipCountry',
#      'path': ['citizenship_name'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['ТАДЖИКИСТАН', 'УЗБЕКИСТАН', 'ТАДЖИКИСТАН'],
#      'types_seen': ['string'],
#      'description': 'Страна гражданства предпринимателя.'},
#     {'name': 'EntrepreneurFormCode',
#      'path': ['code_form_ind_entrep'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['1', '1', '1'],
#      'types_seen': ['string'],
#      'description': 'Код организационно-правовой формы ИП.'},
#     {'name': 'RecordProcessingDate',
#      'path': ['date_exec'],
#      'type': 'date',
#      'nullable': True,
#      'examples': ['2024-10-09', '2024-10-08', '2024-10-08'],
#      'types_seen': ['date'],
#      'description': 'Дата формирования или обработки записи.'},
#     {'name': 'OGRNIPAssignmentDate',
#      'path': ['date_ogrnip'],
#      'type': 'date',
#      'nullable': True,
#      'examples': ['2023-11-14', '2025-01-02', '2020-02-26'],
#      'types_seen': ['date'],
#      'description': 'Дата присвоения ОГРНИП (Основного государственного регистрационного номера ИП).'},
#     {'name': 'DateOfBirth',
#      'path': ['dob'],
#      'type': 'date',
#      'nullable': True,
#      'examples': ['1980-02-29', '1985-08-01', '1968-10-07'],
#      'types_seen': ['date'],
#      'description': 'Дата рождения ИП.'},
#     {'name': 'Email',
#      'path': ['email_ind_entrep'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['zverev.vladimir_syn_7298@YANDEX.RU',
#       'chagochkin.sherzod_syn_5414@GMAIL.COM',
#       'aandrei_4_syn_3305@MAIL.RU'],
#      'types_seen': ['string'],
#      'description': 'Адрес электронной почты ИП.'},
#     {'name': 'ErrorCode',
#      'path': ['error_code'],
#      'type': 'int32',
#      'nullable': True,
#      'examples': [0, 0, 0],
#      'types_seen': ['int32'],
#      'description': 'Код ошибки при обработке записи (если 0 — ошибок нет).'},
#     {'name': 'NationalIDCard',
#      'path': ['id_card'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['77 82 349990', '503461406', '34 68 741072'],
#      'types_seen': ['string'],
#      'description': 'Номер удостоверения личности (паспорт или иной документ).'},
#     {'name': 'ForeignCitizenID',
#      'path': ['id_card_alien_for_rus'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['32№2986662', '40№2974004', '28№8649028'],
#      'types_seen': ['string'],
#      'description': 'Документ, удостоверяющий личность иностранного гражданина.'},
#     {'name': 'RegistrationAuthorityCode',
#      'path': ['inf_authority_reg_ind_entrep_code'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['5800', '5800', '5800'],
#      'types_seen': ['string'],
#      'description': 'Код налогового органа, зарегистрировавшего ИП.'},
#     {'name': 'RegistrationAuthorityName',
#      'path': ['inf_authority_reg_ind_entrep_name'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['Управление Федеральной налоговой службы по Пензенской области',
#       'Управление Федеральной налоговой службы по Пензенской области',
#       'Управление Федеральной налоговой службы по Пензенской области'],
#      'types_seen': ['string'],
#      'description': 'Наименование налогового органа регистрации ИП.'},
#     {'name': 'PrimaryOKVEDCode',
#      'path': ['inf_okved_code'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['01.25.1', '43.39', '43.29'],
#      'types_seen': ['string'],
#      'description': 'Основной код ОКВЭД деятельности ИП.'},
#     {'name': 'PrimaryOKVEDName',
#      'path': ['inf_okved_name'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['Выращивание прочих плодовых и ягодных культур',
#       'Производство прочих отделочных и завершающих работ',
#       'Производство прочих строительно-монтажных работ'],
#      'types_seen': ['string'],
#      'description': 'Наименование основного вида деятельности по ОКВЭД.'},
#     {'name': 'InitialRegistrationDate',
#      'path': ['inf_reg_ind_entrep_date'],
#      'type': 'date',
#      'nullable': True,
#      'examples': ['1996-07-05', '1995-04-27', '1999-08-30'],
#      'types_seen': ['date'],
#      'description': 'Дата первичной регистрации ИП.'},
#     {'name': 'InitialRegistrationNumber',
#      'path': ['inf_reg_ind_entrep_num'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['ССА № 6', '99/05237', '93/51166'],
#      'types_seen': ['string'],
#      'description': 'Номер первичной регистрации ИП.'},
#     {'name': 'TaxAuthorityName',
#      'path': ['inf_reg_tax_ind_entrep'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['Управление Федеральной налоговой службы по Пензенской области',
#       'Управление Федеральной налоговой службы по Пензенской области',
#       'Управление Федеральной налоговой службы по Пензенской области'],
#      'types_seen': ['string'],
#      'description': 'Наименование налогового органа по месту учета ИП.'},
#     {'name': 'StatusCode',
#      'path': ['inf_status_ind_entrep_code'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['110', '110', '111'],
#      'types_seen': ['string'],
#      'description': 'Код текущего статуса ИП.'},
#     {'name': 'StatusDescription',
#      'path': ['inf_status_ind_entrep_name'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['Принято решение о предстоящем исключении недействующего ИП из ЕГРИП',
#       'Принято решение о предстоящем исключении недействующего ИП из ЕГРИП',
#       'Принято решение о предстоящем исключении ИП из ЕГРИП (пп. «б» п.2 Закона № 129-ФЗ)'],
#      'types_seen': ['string'],
#      'description': 'Описание текущего статуса ИП.'},
#     {'name': 'TerminationReasonCode',
#      'path': ['inf_stop_ind_entrep_code'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['201', '201', '209'],
#      'types_seen': ['string'],
#      'description': 'Код причины прекращения деятельности ИП.'},
#     {'name': 'TerminationReasonDescription',
#      'path': ['inf_stop_ind_entrep_name'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['Индивидуальный предприниматель прекратил деятельность в связи с принятием им соответствующего решения',
#       'Индивидуальный предприниматель прекратил деятельность в связи с принятием им соответствующего решения',
#       'Недействующий ИП исключен из ЕГРИП'],
#      'types_seen': ['string'],
#      'description': 'Описание причины прекращения деятельности ИП.'},
#     {'name': 'FirstName',
#      'path': ['inf_surname_ind_entrep_firstname'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['ВЛАДИМИР', 'МАКСИМ', 'ШЕРЗОД'],
#      'types_seen': ['string'],
#      'description': 'Имя ИП.'},
#     {'name': 'Patronymic',
#      'path': ['inf_surname_ind_entrep_midname'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['ЕВГЕНЬЕВИЧ', 'АЛЕКСАНДРОВИЧ', 'ЮРЬЕВИЧ'],
#      'types_seen': ['string'],
#      'description': 'Отчество ИП.'},
#     {'name': 'GenderCode',
#      'path': ['inf_surname_ind_entrep_sex'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['1', '1', '1'],
#      'types_seen': ['string'],
#      'description': 'Пол ИП (1 — мужской, 2 — женский).'},
#     {'name': 'LastName',
#      'path': ['inf_surname_ind_entrep_surname'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['ЗВЕРЕВ', 'БАЛУЕВ', 'ЧАГОЧКИН'],
#      'types_seen': ['string'],
#      'description': 'Фамилия ИП.'},
#     {'name': 'BirthCertificateFirstName',
#      'path': ['inf_surname_ind_entrep_zags_firstname'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['СОФЬЯ', 'ЛЮДМИЛА', 'ТАТЬЯНА'],
#      'types_seen': ['string'],
#      'description': 'Имя по записи акта гражданского состояния (ЗАГС).'},
#     {'name': 'BirthCertificatePatronymic',
#      'path': ['inf_surname_ind_entrep_zags_midname'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['АЛЕКСАНДРОВНА', 'ВЛАДИМИРОВНА', 'ХАБИНУРОВНА'],
#      'types_seen': ['string'],
#      'description': 'Отчество по ЗАГС.'},
#     {'name': 'BirthCertificateLastName',
#      'path': ['inf_surname_ind_entrep_zags_surname'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['ШТУКЕРТ', 'МЕЗЕНЦЕВА', 'ЗАВАРЗИНА'],
#      'types_seen': ['string'],
#      'description': 'Фамилия по ЗАГС.'},
#     {'name': 'INN',
#      'path': ['innfl'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['301127163757', '606163038359', '886737772797'],
#      'types_seen': ['string'],
#      'description': 'ИНН физического лица (ИП).'},
#     {'name': 'PensionFundNumber',
#      'path': ['insured_pf'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['305481831532', '247538274786', '483204952719'],
#      'types_seen': ['string'],
#      'description': 'Страховой номер в Пенсионном фонде (СНИЛС).'},
#     {'name': 'SocialInsuranceNumber',
#      'path': ['insuref_fss'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['173856101397129', '856471362694236', '305234329718883'],
#      'types_seen': ['string'],
#      'description': 'Регистрационный номер в Фонде социального страхования.'},
#     {'name': 'EntrepreneurFormName',
#      'path': ['name_form_ind_entrep'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['Индивидуальный предприниматель',
#       'Индивидуальный предприниматель',
#       'Индивидуальный предприниматель'],
#      'types_seen': ['string'],
#      'description': 'Полное наименование организационно-правовой формы ИП.'},
#     {'name': 'OGRNIP',
#      'path': ['ogrnip'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['865363287164043', '633724687498507', '031125119070468'],
#      'types_seen': ['string'],
#      'description': 'ОГРНИП (Основной государственный регистрационный номер ИП).'},
#     {'name': 'RecordProcessingTimestamp',
#      'path': ['process_dttm'],
#      'type': 'timestamp64(ms)',
#      'nullable': True,
#      'examples': ['2024-10-09T21:07:09.765+03:00',
#       '2024-10-09T21:07:09.765+03:00',
#       '2024-10-09T21:07:09.765+03:00'],
#      'types_seen': ['timestamp64(ms)'],
#      'description': 'Метка времени обработки записи.'}],
#    'description': 'Сущность, содержащая основную информацию об индивидуальном предпринимателе в России.'},
#   {'name': 'EntrepreneurOKVEDOptional',
#    'path': ['inf_okved_opt'],
#    'depth': 1,
#    'parent': 'IndividualEntrepreneur',
#    'primary_key': ['rec_id', 'idx1'],
#    'columns': [{'name': 'OKVEDCode',
#      'path': ['attr_КодОКВЭД'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['38.49', '94.01', '81.42'],
#      'types_seen': ['string'],
#      'description': 'Код дополнительного вида деятельности по ОКВЭД.'},
#     {'name': 'OKVEDName',
#      'path': ['attr_НаимОКВЭД'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['Предоставление услуг в области растениеводства',
#       'Торговля оптовая цветами и растениями',
#       'Прочие виды полиграфической деятельности'],
#      'types_seen': ['string'],
#      'description': 'Наименование дополнительного вида деятельности по ОКВЭД.'},
#     {'name': 'OKVEDVersion',
#      'path': ['attr_ПрВерсОКВЭД'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['2014', '2014', '2014'],
#      'types_seen': ['string'],
#      'description': 'Версия классификатора ОКВЭД.'},
#     {'name': 'GRNIPNumber',
#      'path': ['ГРНИПДата', 'attr_ГРНИП'],
#      'type': 'string',
#      'nullable': True,
#      'examples': ['501892037413202', '196664199989513', '665461963844494'],
#      'types_seen': ['string'],
#      'description': 'ГРНИП записи по дополнительному виду деятельности.'},
#     {'name': 'GRNIPRecordDate',
#      'path': ['ГРНИПДата', 'attr_ДатаЗаписи'],
#      'type': 'date',
#      'nullable': True,
#      'examples': ['2024-06-07', '2023-12-20', '2023-05-14'],
#      'types_seen': ['date'],
#      'description': 'Дата внесения записи о дополнительной деятельности в ЕГРИП.'}],
#    'description': 'Сущность, содержащая дополнительные коды ОКВЭД, относящиеся к индивидуальному предпринимателю.'}],
#  'relations': [{'name': 'fk___root____inf_okved_opt_to___root__',
#    'from_table': '__root____inf_okved_opt',
#    'to_table': '__root__',
#    'from_columns': ['rec_id'],
#    'to_columns': ['rec_id'],
#    'cardinality': 'many-to-one'}],
#  'type_system': {'canonical': {'string': {'pg': 'text',
#     'ch': 'String',
#     'py': 'str'},
#    'int32': {'pg': 'integer', 'ch': 'Int32', 'py': 'int'},
#    'int64': {'pg': 'bigint', 'ch': 'Int64', 'py': 'int'},
#    'float64': {'pg': 'double precision', 'ch': 'Float64', 'py': 'float'},
#    'decimal(p,s)': {'pg': 'numeric({p},{s})',
#     'ch': 'Decimal({p},{s})',
#     'py': 'decimal.Decimal'},
#    'bool': {'pg': 'boolean', 'ch': 'Bool', 'py': 'bool'},
#    'date': {'pg': 'date', 'ch': 'Date32', 'py': 'datetime.date'},
#    'timestamp': {'pg': 'timestamptz',
#     'ch': "DateTime('UTC')",
#     'py': 'datetime.datetime'},
#    'timestamp64(ms)': {'pg': 'timestamptz',
#     'ch': "DateTime64(3, 'UTC')",
#     'py': 'datetime.datetime'},
#    'json': {'pg': 'jsonb', 'ch': 'String', 'py': 'typing.Any'}},
#   'synonyms': {'text': 'string',
#    'varchar': 'string',
#    'bigint': 'int64',
#    'integer': 'int32',
#    'int4': 'int32',
#    'int8': 'int64',
#    'double': 'float64',
#    'double precision': 'float64',
#    'numeric': 'decimal(p,s)',
#    'decimal': 'decimal(p,s)',
#    'timestamptz': 'timestamp',
#    'timestampz': 'timestamp',
#    'datetime': 'timestamp',
#    'datetime64': 'timestamp64(ms)',
#    'jsonb': 'json',
#    'uint8': 'bool'},
#   'fallback': 'string'},
#  'notes': ['root = массив записей; для каждого пути до массива создаётся сущность (TABLE-PER-PATH)',
#   'скалярные поля объектов разворачиваются в колонки с префиксом key__sub__leaf',
#   'nullable=true если встречались null или отсутствие поля',
#   'при смешанных типах берётся безопасный тип (int→int64; int+float→float64; иное→string)']}

# %%
from ddl_postgres import emit_ddl_pg
from ddl_clickhouse import emit_ddl_ch

# profile — это итоговый профиль (после применения патча)
ddl_pg = emit_ddl_pg(final_prof, types_yaml_path="config/types.yaml")
ddl_ch = emit_ddl_ch(final_prof, types_yaml_path="config/types.yaml", database="mydb")  # database опционально

print(ddl_pg)
print(ddl_ch)
# Out:
# CREATE TABLE IF NOT EXISTS "IndividualEntrepreneur" (
#   "rec_id" BIGINT NOT NULL,
#   "CitizenshipTypeCode" text,
#   "CitizenshipCountry" text,
#   "EntrepreneurFormCode" text,
#   "RecordProcessingDate" date,
#   "OGRNIPAssignmentDate" date,
#   "DateOfBirth" date,
#   "Email" text,
#   "ErrorCode" integer,
#   "NationalIDCard" text,
#   "ForeignCitizenID" text,
#   "RegistrationAuthorityCode" text,
#   "RegistrationAuthorityName" text,
#   "PrimaryOKVEDCode" text,
#   "PrimaryOKVEDName" text,
#   "InitialRegistrationDate" date,
#   "InitialRegistrationNumber" text,
#   "TaxAuthorityName" text,
#   "StatusCode" text,
#   "StatusDescription" text,
#   "TerminationReasonCode" text,
#   "TerminationReasonDescription" text,
#   "FirstName" text,
#   "Patronymic" text,
#   "GenderCode" text,
#   "LastName" text,
#   "BirthCertificateFirstName" text,
#   "BirthCertificatePatronymic" text,
#   "BirthCertificateLastName" text,
#   "INN" text,
#   "PensionFundNumber" text,
#   "SocialInsuranceNumber" text,
#   "EntrepreneurFormName" text,
#   "OGRNIP" text,
#   "RecordProcessingTimestamp" timestamptz,
#   CONSTRAINT "IndividualEntrepreneur__pk" PRIMARY KEY ("rec_id")
# );
#
# CREATE TABLE IF NOT EXISTS "EntrepreneurOKVEDOptional" (
#   "rec_id" BIGINT NOT NULL,
#   "idx1" INTEGER NOT NULL,
#   "OKVEDCode" text,
#   "OKVEDName" text,
#   "OKVEDVersion" text,
#   "GRNIPNumber" text,
#   "GRNIPRecordDate" date,
#   CONSTRAINT "EntrepreneurOKVEDOptional__pk" PRIMARY KEY ("rec_id", "idx1"),
#   CONSTRAINT "fk_EntrepreneurOKVEDOptional_to_IndividualEntrepreneur" FOREIGN KEY ("rec_id") REFERENCES "IndividualEntrepreneur" ("rec_id")
# );
#
# CREATE TABLE IF NOT EXISTS `mydb`.`IndividualEntrepreneur` (
#   `rec_id` UInt64,
#   `CitizenshipTypeCode` Nullable(String),
#   `CitizenshipCountry` Nullable(String),
#   `EntrepreneurFormCode` Nullable(String),
#   `RecordProcessingDate` Nullable(Date32),
#   `OGRNIPAssignmentDate` Nullable(Date32),
#   `DateOfBirth` Nullable(Date32),
#   `Email` Nullable(String),
#   `ErrorCode` Nullable(Int32),
#   `NationalIDCard` Nullable(String),
#   `ForeignCitizenID` Nullable(String),
#   `RegistrationAuthorityCode` Nullable(String),
#   `RegistrationAuthorityName` Nullable(String),
#   `PrimaryOKVEDCode` Nullable(String),
#   `PrimaryOKVEDName` Nullable(String),
#   `InitialRegistrationDate` Nullable(Date32),
#   `InitialRegistrationNumber` Nullable(String),
#   `TaxAuthorityName` Nullable(String),
#   `StatusCode` Nullable(String),
#   `StatusDescription` Nullable(String),
#   `TerminationReasonCode` Nullable(String),
#   `TerminationReasonDescription` Nullable(String),
#   `FirstName` Nullable(String),
#   `Patronymic` Nullable(String),
#   `GenderCode` Nullable(String),
#   `LastName` Nullable(String),
#   `BirthCertificateFirstName` Nullable(String),
#   `BirthCertificatePatronymic` Nullable(String),
#   `BirthCertificateLastName` Nullable(String),
#   `INN` Nullable(String),
#   `PensionFundNumber` Nullable(String),
#   `SocialInsuranceNumber` Nullable(String),
#   `EntrepreneurFormName` Nullable(String),
#   `OGRNIP` Nullable(String),
#   `RecordProcessingTimestamp` Nullable(DateTime64(3, 'UTC'))
# )
# ENGINE = MergeTree
# ORDER BY (`rec_id`);
#
# CREATE TABLE IF NOT EXISTS `mydb`.`EntrepreneurOKVEDOptional` (
#   `rec_id` UInt64,
#   `idx1` UInt32,
#   `OKVEDCode` Nullable(String),
#   `OKVEDName` Nullable(String),
#   `OKVEDVersion` Nullable(String),
#   `GRNIPNumber` Nullable(String),
#   `GRNIPRecordDate` Nullable(Date32)
# )
# ENGINE = MergeTree
# ORDER BY (`rec_id`, `idx1`);

# %% [markdown]
# # Создадим DBML

# %%
import json
from dbml_from_profile import emit_dbml, save_dbml

dbml_text = emit_dbml(final_prof, project_database_type="Generic")
print(dbml_text[:500], "...")

# или сохранить в файл
save_dbml(final_prof, "schema.dbml", project_database_type="Generic")
# Out:
# Project {
#   database_type: 'Generic'
# }
#
# Table "IndividualEntrepreneur" {
#   "rec_id" bigint [pk, not null]
#   "CitizenshipTypeCode" text [null, note: 'Код типа гражданства (например, гражданин РФ, иностранец и т.п.).']
#   "CitizenshipCountry" text [null, note: 'Страна гражданства предпринимателя.']
#   "EntrepreneurFormCode" text [null, note: 'Код организационно-правовой формы ИП.']
#   "RecordProcessingDate" date [null, note: 'Дата формирования или обработки записи.']
#   "OGRNIPAssignmentDate" date [nu ...

# %% [markdown]
# # Итератор для ETL в будущем

# %%
from row_iterator import iter_rows, get_table_columns


import json

with open("data/raw/part1.json.trimmed.json", "r", encoding="utf-8") as f:
    records = json.load(f)  # список dict'ов

# records: это iterable JSON-объектов (например, list(json.load(f)))
cols = get_table_columns(final_prof)

for table, row in iter_rows(final_prof, records):
    # row содержит PK и все данные по колонкам этого table
    # Можно буферизовать и грузить батчами:
    #   - PostgreSQL: COPY table (cols[table]) FROM STDIN
    #   - ClickHouse: INSERT INTO table FORMAT JSONEachRow (нужно сериализовать row в JSON)
    pass

# %% [markdown]
# # Удалим все таблицы для начала

# %%
import json
from ch_reset import drop_ch_tables_for_profile, recreate_and_load_ch
http = "http://127.0.0.1:8123"
db = "analytics"

drop_ch_tables_for_profile(http, final_prof, db)
# recreate_and_load_ch(http, final_prof, records, database=db)

# %%
import psycopg2, json
from pg_reset import drop_pg_tables_for_profile, recreate_and_load_pg

conn = psycopg2.connect("postgresql://postgres:postgres@localhost:5432/analytics")
drop_pg_tables_for_profile(conn, final_prof, schema="public")
# recreate_and_load_pg(conn, final_prof, records, schema="public")
conn.close()

# %% [markdown]
# # Загрузка в Постгрес

# %%
import json, psycopg2
from ddl_postgres import emit_ddl_pg
from load_postgres import copy_into_pg

# %%
with open("data/raw/part1.json.trimmed.json", "r", encoding="utf-8") as f:
    records = json.load(f)

# %%
conn = psycopg2.connect("postgresql://postgres:postgres@localhost:5432/analytics")

# %%
ddl = emit_ddl_pg(final_prof, types_yaml_path="config/types.yaml")
with conn.cursor() as cur:
    cur.execute("SET client_min_messages = WARNING")
    # psycopg2 нормально выполняет несколько CREATE в одном execute,
    # но если вдруг драйвер ругнётся — можно разбить по ';'
    cur.execute(ddl)
conn.commit()

# %%
copy_into_pg(conn, final_prof, records, schema="public", batch_size=50_000)
conn.close()

# %%
import psycopg2, json
from pg_introspect import (
    table_exists, list_tables, describe_columns,
    primary_key, foreign_keys, row_count,
    validate_schema_against_profile
)

# подключение
conn = psycopg2.connect("postgresql://postgres:postgres@localhost:5432/analytics")

print(list_tables(conn, "public"))
print(table_exists(conn, "public", "IndividualEntrepreneur"))          # True/False
print(primary_key(conn, "public", "IndividualEntrepreneur"))           # ['rec_id']
print(describe_columns(conn, "public", "IndividualEntrepreneur")[:5])  # первые 5 колонок
print(foreign_keys(conn, "public", "EntrepreneurOKVEDOptional"))       # FK -> parent
print(row_count(conn, "public", "IndividualEntrepreneur"))             # количество строк
print(row_count(conn, "public", "EntrepreneurOKVEDOptional"))

print(validate_schema_against_profile(conn, final_prof, schema="public"))

conn.close()
# Out:
# ['EntrepreneurOKVEDOptional', 'IndividualEntrepreneur', 'individual_entrepreneur', 'okved_main', 'okved_optional']
# True
# ['rec_id']
# [{'name': 'rec_id', 'nullable': False, 'data_type': 'bigint', 'udt_name': 'int8', 'char_len': None, 'numeric_precision': 64, 'numeric_scale': 0}, {'name': 'CitizenshipTypeCode', 'nullable': True, 'data_type': 'text', 'udt_name': 'text', 'char_len': None, 'numeric_precision': None, 'numeric_scale': None}, {'name': 'CitizenshipCountry', 'nullable': True, 'data_type': 'text', 'udt_name': 'text', 'char_len': None, 'numeric_precision': None, 'numeric_scale': None}, {'name': 'EntrepreneurFormCode', 'nullable': True, 'data_type': 'text', 'udt_name': 'text', 'char_len': None, 'numeric_precision': None, 'numeric_scale': None}, {'name': 'RecordProcessingDate', 'nullable': True, 'data_type': 'date', 'udt_name': 'date', 'char_len': None, 'numeric_precision': None, 'numeric_scale': None}]
# [{'name': 'fk_EntrepreneurOKVEDOptional_to_IndividualEntrepreneur', 'columns': ['rec_id'], 'ref_table': ('public', 'IndividualEntrepreneur'), 'ref_columns': ['rec_id']}]
# 5000
# 38789
# SUCCESS

# %% [markdown]
# # Загрузка в КЛикхаус

# %%
from ddl_clickhouse import emit_ddl_ch
from ch_exec import ch_exec_many

ddl_ch = emit_ddl_ch(final_prof, types_yaml_path="config/types.yaml", database="analytics")

# c хоста:
ch_exec_many("http://localhost:8123", ddl_ch, database="analytics")

# если вызываешь из контейнера Airflow — меняй хост:
# ch_exec_many("http://clickhouse:8123", ddl_ch, database="analytics")

# %%
from load_clickhouse import insert_into_ch

insert_into_ch(
    "http://127.0.0.1:8123",
    final_prof,
    records,
    database="analytics",     # таблицы уже созданы в analytics
    batch_size=100_000,
    cast=True,                # важный момент из-за timestamp64
    trust_env=False           # игнорируем системные HTTP(S)_PROXY
)

# %%
import json
from ch_introspect import (
    ch_ping, list_tables, table_exists, describe_columns,
    table_engine_and_keys, row_count, validate_schema_against_profile_ch
)

http = "http://127.0.0.1:8123"
db = "analytics"

# 0) проверка соединения
ch_ping(http)

# 1) список таблиц
print(list_tables(http, db))

# 2) существует ли таблица
print(table_exists(http, db, "IndividualEntrepreneur"))

# 3) описание колонок
print(describe_columns(http, db, "IndividualEntrepreneur")[:5])

# 4) ключи / движок
print(table_engine_and_keys(http, db, "EntrepreneurOKVEDOptional"))

# 5) количество строк
print(row_count(http, "analytics", "IndividualEntrepreneur"))
print(row_count(http, "analytics", "EntrepreneurOKVEDOptional"))


# 6) валидация против итогового профиля
print(validate_schema_against_profile_ch(http, final_prof, db, types_yaml_path="config/types.yaml"))
