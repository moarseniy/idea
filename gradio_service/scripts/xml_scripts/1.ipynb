# %%
from xml2graph import build_graph_from_address
from profile2entities import profile_to_entities

profile = build_graph_from_address("part18.xml")  # или URL, или XML-строка
entities = profile_to_entities(profile, table_name_style="short")

# дальше entities — это dict, можно сериализовать/использовать в ETL

# %%
prompt = """

Следующий профиль в формате json задает собой реляционную структуру в БД. Твоя задача дать названия бизнес-сущностям и всем полям.

Профиль:

""" + str(entities) + """
Ответ выдай строго чистым JSON без комментариев ни до не после. Структура json ответа строго такая:

{
  "version": 1,
  "entities": [
    {
      "path": "<entity_path_from_entities_json>",
      "alias": "<entity_alias_snake_case_max63>",
      "title": "<entity_human_title>",
      "description": "<entity_description>",
      "fields": [
        {
          "path": "<field_rel_path_from_entities_json>",
          "alias": "<field_alias_snake_case_max63>",
          "title": "<field_human_title>",
          "description": "<field_description>"
        }
      ]
    },
    {
      "path": "<entity_path_from_entities_json_2>",
      "alias": "<entity2_alias_snake_case_max63>",
      "title": "<entity2_human_title>",
      "description": "<entity2_description>",
      "fields": [
        {
          "path": "<field_rel_path_from_entities_json_2>",
          "alias": "<field2_alias_snake_case_max63>",
          "title": "<field2_human_title>",
          "description": "<field2_description>"
        }
      ]
    }
  ]
}
"""

# %%
from entities_patch_validator import validate_patch
import json

with open("try1.json", "r", encoding="utf-8") as f:
    patch_json = json.load(f) 

# base_entities и patch_json — это уже загруженные dict'ы
result = validate_patch(entities, patch_json)
if result != "SUCCESS":
    # обработать ошибки
    print(result)

# %%
from final_profile import make_final_profile
final_spec = make_final_profile(entities, patch_json, "part18.xml")

# %%
final_spec
# Out:
# {'version': 1,
#  'source': {'xml': 'part18.xml'},
#  'typeset': 'canonical',
#  'tables': [{'entity_path': '/root/item',
#    'name': 'item',
#    'alias': 'real_estate_object',
#    'title': 'Объект недвижимости',
#    'description': 'Основная сущность, представляющая объект недвижимости с кадастровыми, техническими и учетными характеристиками.',
#    'table': 'real_estate_object',
#    'columns': [{'name': 'id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'pk_surrogate',
#      'description': 'Суррогатный первичный ключ.'},
#     {'name': 'unverified_purpose_code',
#      'type': 'int64',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/purpose/code',
#      'is_key_hint': False,
#      'observed': {'non_null': 4, 'nulls': 0, 'samples': 4},
#      'title': 'Код назначения (неподтвержденные данные)',
#      'description': 'Код предполагаемого назначения объекта, не прошедший проверку.'},
#     {'name': 'unverified_purpose_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/purpose/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 4, 'nulls': 0, 'samples': 4},
#      'title': 'Назначение (неподтвержденные данные)',
#      'description': 'Наименование предполагаемого назначения объекта, не прошедшее проверку.'},
#     {'name': 'unverified_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/name',
#      'is_key_hint': False,
#      'observed': {'non_null': 19, 'nulls': 0, 'samples': 19},
#      'title': 'Наименование (неподтвержденные данные)',
#      'description': 'Наименование объекта, указанное без подтверждения.'},
#     {'name': 'unverified_area',
#      'type': 'decimal(6,1)',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/area',
#      'is_key_hint': False,
#      'observed': {'non_null': 13, 'nulls': 0, 'samples': 13},
#      'title': 'Площадь (неподтвержденные данные)',
#      'description': 'Площадь объекта по неподтвержденным данным.'},
#     {'name': 'unverified_floors',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/floors',
#      'is_key_hint': False,
#      'observed': {'non_null': 1, 'nulls': 0, 'samples': 1},
#      'title': 'Этажность (неподтвержденные данные)',
#      'description': 'Количество этажей по неподтвержденным данным.'},
#     {'name': 'unverified_underground_floors',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/underground_floors',
#      'is_key_hint': False,
#      'observed': {'non_null': 0, 'nulls': 0, 'samples': 0},
#      'title': 'Подземные этажи (неподтвержденные данные)',
#      'description': 'Количество подземных этажей по неподтвержденным данным.'},
#     {'name': 'inventory_cost',
#      'type': 'decimal(11,2)',
#      'nullable': True,
#      'source_path': 'dated_info/oti/invent_cost',
#      'is_key_hint': False,
#      'observed': {'non_null': 624, 'nulls': 0, 'samples': 624},
#      'title': 'Инвентаризационная стоимость',
#      'description': 'Оценочная стоимость объекта по данным инвентаризации.'},
#     {'name': 'inventory_letter',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'dated_info/oti/letter',
#      'is_key_hint': False,
#      'observed': {'non_null': 785, 'nulls': 0, 'samples': 785},
#      'title': 'Литера по инвентаризации',
#      'description': 'Обозначение литера (буквенного кода) здания по данным инвентаризации.'},
#     {'name': 'inventory_date',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'dated_info/oti/invent_date',
#      'is_key_hint': False,
#      'observed': {'non_null': 0, 'nulls': 0, 'samples': 0},
#      'title': 'Дата инвентаризации',
#      'description': 'Дата последней инвентаризации объекта.'},
#     {'name': 'inventory_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'dated_info/oti/name_oti',
#      'is_key_hint': False,
#      'observed': {'non_null': 0, 'nulls': 0, 'samples': 0},
#      'title': 'Наименование по инвентаризации',
#      'description': 'Наименование объекта согласно данным технической инвентаризации.'},
#     {'name': 'last_change_record_number',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'metadata/last_change_record_number',
#      'is_key_hint': False,
#      'observed': {'non_null': 1997, 'nulls': 3, 'samples': 2000},
#      'title': 'Номер последней записи изменений',
#      'description': 'Идентификатор последней записи изменений объекта в системе.'},
#     {'name': 'last_container_fixed_at',
#      'type': 'timestamp',
#      'nullable': False,
#      'source_path': 'metadata/last_container_fixed_at',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Дата последней фиксации контейнера',
#      'description': 'Дата фиксации последнего состояния объекта в контейнере данных.'},
#     {'name': 'record_status',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'metadata/status',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Статус записи',
#      'description': 'Текущий статус записи объекта недвижимости.'},
#     {'name': 'cadastral_number',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'object_common_data/cad_number',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Кадастровый номер',
#      'description': 'Уникальный кадастровый номер объекта недвижимости.'},
#     {'name': 'was_previously_registered',
#      'type': 'bool',
#      'nullable': True,
#      'source_path': 'object_common_data/previously_posted',
#      'is_key_hint': False,
#      'observed': {'non_null': 1437, 'nulls': 0, 'samples': 1437},
#      'title': 'Ранее учтённый',
#      'description': 'Признак того, что объект был ранее поставлен на учет.'},
#     {'name': 'quarter_cadastral_number',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'object_common_data/quarter_cad_number',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Кадастровый номер квартала',
#      'description': 'Кадастровый номер квартала, в котором расположен объект.'},
#     {'name': 'object_type_code',
#      'type': 'int64',
#      'nullable': False,
#      'source_path': 'object_common_data/type/code',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Код типа объекта',
#      'description': 'Код, обозначающий тип объекта недвижимости.'},
#     {'name': 'object_type_name',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'object_common_data/type/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Тип объекта',
#      'description': 'Наименование типа объекта недвижимости.'},
#     {'name': 'temporary_info',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'object_common_data/temporary_info',
#      'is_key_hint': False,
#      'observed': {'non_null': 0, 'nulls': 0, 'samples': 0},
#      'title': 'Временная информация',
#      'description': 'Дополнительная временная информация об объекте.'},
#     {'name': 'object_definition',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'object_common_data/definition',
#      'is_key_hint': False,
#      'observed': {'non_null': 0, 'nulls': 0, 'samples': 0},
#      'title': 'Описание объекта',
#      'description': 'Описание или определение объекта недвижимости.'},
#     {'name': 'formation_method_code',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'object_formation/method/code',
#      'is_key_hint': False,
#      'observed': {'non_null': 3, 'nulls': 0, 'samples': 3},
#      'title': 'Код метода образования',
#      'description': 'Код способа образования объекта недвижимости.'},
#     {'name': 'formation_method_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'object_formation/method/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 3, 'nulls': 0, 'samples': 3},
#      'title': 'Метод образования',
#      'description': 'Наименование способа образования объекта.'},
#     {'name': 'declared_area',
#      'type': 'decimal(6,1)',
#      'nullable': True,
#      'source_path': 'params/area',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Заявленная площадь',
#      'description': 'Площадь объекта, заявленная пользователем.'},
#     {'name': 'declared_floors',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/floors',
#      'is_key_hint': False,
#      'observed': {'non_null': 1883, 'nulls': 0, 'samples': 1883},
#      'title': 'Заявленная этажность',
#      'description': 'Количество этажей по заявленным данным.'},
#     {'name': 'wall_material_code',
#      'type': 'int64',
#      'nullable': True,
#      'source_path': 'params/material/code',
#      'is_key_hint': False,
#      'observed': {'non_null': 1655, 'nulls': 0, 'samples': 1655},
#      'title': 'Код материала стен',
#      'description': 'Код материала, из которого выполнены стены объекта.'},
#     {'name': 'wall_material_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/material/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 1655, 'nulls': 0, 'samples': 1655},
#      'title': 'Материал стен',
#      'description': 'Наименование материала стен объекта.'},
#     {'name': 'declared_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/name',
#      'is_key_hint': False,
#      'observed': {'non_null': 1777, 'nulls': 0, 'samples': 1777},
#      'title': 'Заявленное наименование',
#      'description': 'Наименование объекта, указанное заявителем.'},
#     {'name': 'permitted_use_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/permitted_use/name',
#      'is_key_hint': False,
#      'observed': {'non_null': 27, 'nulls': 0, 'samples': 27},
#      'title': 'Разрешенное использование',
#      'description': 'Наименование разрешенного использования объекта.'},
#     {'name': 'declared_purpose_code',
#      'type': 'int64',
#      'nullable': True,
#      'source_path': 'params/purpose/code',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Код назначения (заявленное)',
#      'description': 'Код назначения объекта, заявленный пользователем.'},
#     {'name': 'declared_purpose_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/purpose/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Назначение (заявленное)',
#      'description': 'Наименование назначения объекта, заявленное пользователем.'},
#     {'name': 'year_built',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'params/year_built',
#      'is_key_hint': False,
#      'observed': {'non_null': 1425, 'nulls': 0, 'samples': 1425},
#      'title': 'Год постройки',
#      'description': 'Год завершения строительства объекта.'},
#     {'name': 'year_commissioned',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/year_commisioning',
#      'is_key_hint': False,
#      'observed': {'non_null': 635, 'nulls': 0, 'samples': 635},
#      'title': 'Год ввода в эксплуатацию',
#      'description': 'Год ввода объекта в эксплуатацию.'},
#     {'name': 'declared_underground_floors',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/underground_floors',
#      'is_key_hint': False,
#      'observed': {'non_null': 463, 'nulls': 0, 'samples': 463},
#      'title': 'Подземные этажи (заявленное)',
#      'description': 'Количество подземных этажей по заявленным данным.'},
#     {'name': 'record_number',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'record_info/record_number',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Номер записи',
#      'description': 'Номер учетной записи объекта в системе.'},
#     {'name': 'registration_date',
#      'type': 'timestamp',
#      'nullable': False,
#      'source_path': 'record_info/registration_date',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Дата регистрации',
#      'description': 'Дата государственной регистрации объекта.'},
#     {'name': 'section_number',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'record_info/section_number',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Номер раздела',
#      'description': 'Номер раздела в реестре, к которому относится объект.'},
#     {'name': 'record_cancel_date',
#      'type': 'timestamp',
#      'nullable': True,
#      'source_path': 'record_info/cancel_date',
#      'is_key_hint': False,
#      'observed': {'non_null': 90, 'nulls': 0, 'samples': 90},
#      'title': 'Дата аннулирования записи',
#      'description': 'Дата аннулирования учетной записи объекта.'}],
#    'primary_key': {'columns': ['id'], 'type': 'surrogate'},
#    'natural_key_candidates': ['cadastral_number',
#     'declared_purpose_code',
#     'record_number',
#     'section_number'],
#    'unique': [{'columns': ['cadastral_number',
#       'declared_purpose_code',
#       'record_number',
#       'section_number'],
#      'note': 'Наблюдаемый естественный ключ (из key_hints).'}],
#    'order_by': [],
#    'extract': {'row_xpath': '/root/item',
#     'fields': [{'column': 'unverified_purpose_code',
#       'rel_xpath': 'actual_unverified_data/purpose/code'},
#      {'column': 'unverified_purpose_name',
#       'rel_xpath': 'actual_unverified_data/purpose/value'},
#      {'column': 'unverified_name', 'rel_xpath': 'actual_unverified_data/name'},
#      {'column': 'unverified_area', 'rel_xpath': 'actual_unverified_data/area'},
#      {'column': 'unverified_floors',
#       'rel_xpath': 'actual_unverified_data/floors'},
#      {'column': 'unverified_underground_floors',
#       'rel_xpath': 'actual_unverified_data/underground_floors'},
#      {'column': 'inventory_cost', 'rel_xpath': 'dated_info/oti/invent_cost'},
#      {'column': 'inventory_letter', 'rel_xpath': 'dated_info/oti/letter'},
#      {'column': 'inventory_date', 'rel_xpath': 'dated_info/oti/invent_date'},
#      {'column': 'inventory_name', 'rel_xpath': 'dated_info/oti/name_oti'},
#      {'column': 'last_change_record_number',
#       'rel_xpath': 'metadata/last_change_record_number'},
#      {'column': 'last_container_fixed_at',
#       'rel_xpath': 'metadata/last_container_fixed_at'},
#      {'column': 'record_status', 'rel_xpath': 'metadata/status'},
#      {'column': 'cadastral_number',
#       'rel_xpath': 'object_common_data/cad_number'},
#      {'column': 'was_previously_registered',
#       'rel_xpath': 'object_common_data/previously_posted'},
#      {'column': 'quarter_cadastral_number',
#       'rel_xpath': 'object_common_data/quarter_cad_number'},
#      {'column': 'object_type_code',
#       'rel_xpath': 'object_common_data/type/code'},
#      {'column': 'object_type_name',
#       'rel_xpath': 'object_common_data/type/value'},
#      {'column': 'temporary_info',
#       'rel_xpath': 'object_common_data/temporary_info'},
#      {'column': 'object_definition',
#       'rel_xpath': 'object_common_data/definition'},
#      {'column': 'formation_method_code',
#       'rel_xpath': 'object_formation/method/code'},
#      {'column': 'formation_method_name',
#       'rel_xpath': 'object_formation/method/value'},
#      {'column': 'declared_area', 'rel_xpath': 'params/area'},
#      {'column': 'declared_floors', 'rel_xpath': 'params/floors'},
#      {'column': 'wall_material_code', 'rel_xpath': 'params/material/code'},
#      {'column': 'wall_material_name', 'rel_xpath': 'params/material/value'},
#      {'column': 'declared_name', 'rel_xpath': 'params/name'},
#      {'column': 'permitted_use_name',
#       'rel_xpath': 'params/permitted_use/name'},
#      {'column': 'declared_purpose_code', 'rel_xpath': 'params/purpose/code'},
#      {'column': 'declared_purpose_name', 'rel_xpath': 'params/purpose/value'},
#      {'column': 'year_built', 'rel_xpath': 'params/year_built'},
#      {'column': 'year_commissioned', 'rel_xpath': 'params/year_commisioning'},
#      {'column': 'declared_underground_floors',
#       'rel_xpath': 'params/underground_floors'},
#      {'column': 'record_number', 'rel_xpath': 'record_info/record_number'},
#      {'column': 'registration_date',
#       'rel_xpath': 'record_info/registration_date'},
#      {'column': 'section_number', 'rel_xpath': 'record_info/section_number'},
#      {'column': 'record_cancel_date',
#       'rel_xpath': 'record_info/cancel_date'}]},
#    'parent': {'entity_path': None, 'table': None, 'fk_column': None},
#    'children': [{'entity_path': '/root/item/contour',
#      'table': 'object_contour',
#      'relpath_from_parent': 'contour',
#      'min': 0,
#      'max': 129}]},
#   {'entity_path': '/root/item/contour',
#    'name': 'contour',
#    'alias': 'object_contour',
#    'title': 'Контур объекта',
#    'description': 'Контур объекта недвижимости, описывающий его пространственное положение и форму.',
#    'table': 'object_contour',
#    'columns': [{'name': 'id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'pk_surrogate',
#      'description': 'Суррогатный первичный ключ.'},
#     {'name': 'real_estate_object_id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'fk_parent',
#      'ref_table': 'real_estate_object',
#      'ref_column': 'id',
#      'description': 'Внешний ключ на родительскую сущность.'},
#     {'name': 'spatial_id',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'entity_spatial/sk_id',
#      'is_key_hint': False,
#      'observed': {'non_null': 1719, 'nulls': 0, 'samples': 1719},
#      'title': 'Идентификатор пространственного элемента',
#      'description': 'Уникальный идентификатор пространственного элемента контура.'},
#     {'name': 'spatial_code',
#      'type': 'decimal(3,1)',
#      'nullable': True,
#      'source_path': 'entity_spatial/sk_code/code',
#      'is_key_hint': True,
#      'observed': {'non_null': 934, 'nulls': 0, 'samples': 934},
#      'title': 'Код пространственного элемента',
#      'description': 'Код, определяющий пространственное положение контура.'},
#     {'name': 'spatial_code_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'entity_spatial/sk_code/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 919, 'nulls': 0, 'samples': 919},
#      'title': 'Наименование пространственного кода',
#      'description': 'Наименование, соответствующее коду пространственного элемента.'},
#     {'name': 'contour_definition',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'definition',
#      'is_key_hint': False,
#      'observed': {'non_null': 825, 'nulls': 0, 'samples': 825},
#      'title': 'Описание контура',
#      'description': 'Текстовое описание границ контура объекта.'},
#     {'name': 'contour_number',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'number_pp',
#      'is_key_hint': True,
#      'observed': {'non_null': 829, 'nulls': 0, 'samples': 829},
#      'title': 'Порядковый номер контура',
#      'description': 'Порядковый номер контура в составе объекта.'}],
#    'primary_key': {'columns': ['id'], 'type': 'surrogate'},
#    'natural_key_candidates': ['contour_number', 'spatial_code'],
#    'unique': [{'columns': ['contour_number', 'spatial_code'],
#      'note': 'Наблюдаемый естественный ключ (из key_hints).'},
#     {'columns': ['real_estate_object_id', 'contour_number'],
#      'note': 'Уникальность дочерних строк в рамках родителя (FK + order_by).'}],
#    'order_by': ['contour_number'],
#    'extract': {'row_xpath': '/root/item/contour',
#     'fields': [{'column': 'spatial_id', 'rel_xpath': 'entity_spatial/sk_id'},
#      {'column': 'spatial_code', 'rel_xpath': 'entity_spatial/sk_code/code'},
#      {'column': 'spatial_code_name',
#       'rel_xpath': 'entity_spatial/sk_code/value'},
#      {'column': 'contour_definition', 'rel_xpath': 'definition'},
#      {'column': 'contour_number', 'rel_xpath': 'number_pp'}]},
#    'parent': {'entity_path': '/root/item',
#     'table': 'real_estate_object',
#     'fk_column': 'real_estate_object_id'},
#    'children': [{'entity_path': '/root/item/contour/entity_spatial/spatials_elements/spatial_element',
#      'table': 'spatial_element',
#      'relpath_from_parent': 'entity_spatial/spatials_elements/spatial_element',
#      'min': 0,
#      'max': 99}]},
#   {'entity_path': '/root/item/contour/entity_spatial/spatials_elements/spatial_element',
#    'name': 'spatial_element',
#    'alias': 'spatial_element',
#    'title': 'Пространственный элемент',
#    'description': 'Пространственный элемент, входящий в состав контура, определяющий его часть на определенном уровне.',
#    'table': 'spatial_element',
#    'columns': [{'name': 'id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'pk_surrogate',
#      'description': 'Суррогатный первичный ключ.'},
#     {'name': 'object_contour_id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'fk_parent',
#      'ref_table': 'object_contour',
#      'ref_column': 'id',
#      'description': 'Внешний ключ на родительскую сущность.'},
#     {'name': 'unit_type_code',
#      'type': 'int32',
#      'nullable': False,
#      'source_path': 'type_unit/code',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Код типа единицы',
#      'description': 'Код, определяющий тип единицы измерения или пространственного элемента.'},
#     {'name': 'unit_type_name',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'type_unit/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Тип единицы',
#      'description': 'Наименование типа единицы или пространственного элемента.'},
#     {'name': 'contour_level_code',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'level_contour/code',
#      'is_key_hint': True,
#      'observed': {'non_null': 735, 'nulls': 0, 'samples': 735},
#      'title': 'Код уровня контура',
#      'description': 'Код уровня, на котором расположен пространственный элемент.'},
#     {'name': 'contour_level_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'level_contour/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 735, 'nulls': 0, 'samples': 735},
#      'title': 'Уровень контура',
#      'description': 'Наименование уровня расположения пространственного элемента.'},
#     {'name': 'seq',
#      'type': 'int32',
#      'nullable': False,
#      'role': 'sequence_within_parent',
#      'description': 'Порядковый номер строки в рамках родительской записи.'}],
#    'primary_key': {'columns': ['id'], 'type': 'surrogate'},
#    'natural_key_candidates': ['contour_level_code', 'unit_type_code'],
#    'unique': [{'columns': ['contour_level_code', 'unit_type_code'],
#      'note': 'Наблюдаемый естественный ключ (из key_hints).'},
#     {'columns': ['object_contour_id', 'seq'],
#      'note': 'Уникальность дочерних строк в рамках родителя (FK + order_by).'}],
#    'order_by': ['seq'],
#    'extract': {'row_xpath': '/root/item/contour/entity_spatial/spatials_elements/spatial_element',
#     'fields': [{'column': 'unit_type_code', 'rel_xpath': 'type_unit/code'},
#      {'column': 'unit_type_name', 'rel_xpath': 'type_unit/value'},
#      {'column': 'contour_level_code', 'rel_xpath': 'level_contour/code'},
#      {'column': 'contour_level_name', 'rel_xpath': 'level_contour/value'}]},
#    'parent': {'entity_path': '/root/item/contour',
#     'table': 'object_contour',
#     'fk_column': 'object_contour_id'},
#    'children': [{'entity_path': '/root/item/contour/entity_spatial/spatials_elements/spatial_element/ordinates/ordinate',
#      'table': 'coordinate_point',
#      'relpath_from_parent': 'ordinates/ordinate',
#      'min': 0,
#      'max': 922}]},
#   {'entity_path': '/root/item/contour/entity_spatial/spatials_elements/spatial_element/ordinates/ordinate',
#    'name': 'ordinate',
#    'alias': 'coordinate_point',
#    'title': 'Опорная точка (ордината)',
#    'description': 'Координатная точка, определяющая геометрию пространственного элемента.',
#    'table': 'coordinate_point',
#    'columns': [{'name': 'id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'pk_surrogate',
#      'description': 'Суррогатный первичный ключ.'},
#     {'name': 'spatial_element_id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'fk_parent',
#      'ref_table': 'spatial_element',
#      'ref_column': 'id',
#      'description': 'Внешний ключ на родительскую сущность.'},
#     {'name': 'point_sequence_number',
#      'type': 'int32',
#      'nullable': False,
#      'source_path': 'ord_nmb',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Порядковый номер точки',
#      'description': 'Порядковый номер координатной точки в описании геометрии.'},
#     {'name': 'coordinate_x',
#      'type': 'decimal(9,2)',
#      'nullable': False,
#      'source_path': 'x',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Координата X',
#      'description': 'Координата X точки в системе координат.'},
#     {'name': 'coordinate_y',
#      'type': 'decimal(8,2)',
#      'nullable': False,
#      'source_path': 'y',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Координата Y',
#      'description': 'Координата Y точки в системе координат.'},
#     {'name': 'coordinate_z',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'z',
#      'is_key_hint': False,
#      'observed': {'non_null': 654, 'nulls': 0, 'samples': 654},
#      'title': 'Координата Z',
#      'description': 'Координата Z точки (высота), если задана.'},
#     {'name': 'geopoint_accuracy',
#      'type': 'decimal(3,2)',
#      'nullable': True,
#      'source_path': 'delta_geopoint',
#      'is_key_hint': False,
#      'observed': {'non_null': 1130, 'nulls': 0, 'samples': 1130},
#      'title': 'Точность геоточки',
#      'description': 'Допустимое отклонение координаты точки.'},
#     {'name': 'geopoint_number',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'num_geopoint',
#      'is_key_hint': True,
#      'observed': {'non_null': 1116, 'nulls': 0, 'samples': 1116},
#      'title': 'Номер геоточки',
#      'description': 'Идентификатор геоточки в пределах пространственного элемента.'},
#     {'name': 'geopoint_determination_code',
#      'type': 'int64',
#      'nullable': True,
#      'source_path': 'geopoint_opred/code',
#      'is_key_hint': True,
#      'observed': {'non_null': 166, 'nulls': 0, 'samples': 166},
#      'title': 'Код способа определения точки',
#      'description': 'Код, обозначающий способ определения координат точки.'},
#     {'name': 'geopoint_determination_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'geopoint_opred/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 166, 'nulls': 0, 'samples': 166},
#      'title': 'Способ определения точки',
#      'description': 'Наименование способа определения координат точки.'}],
#    'primary_key': {'columns': ['id'], 'type': 'surrogate'},
#    'natural_key_candidates': ['geopoint_determination_code',
#     'geopoint_number',
#     'point_sequence_number'],
#    'unique': [{'columns': ['geopoint_determination_code',
#       'geopoint_number',
#       'point_sequence_number'],
#      'note': 'Наблюдаемый естественный ключ (из key_hints).'},
#     {'columns': ['spatial_element_id',
#       'point_sequence_number',
#       'geopoint_number'],
#      'note': 'Уникальность дочерних строк в рамках родителя (FK + order_by).'}],
#    'order_by': ['point_sequence_number', 'geopoint_number'],
#    'extract': {'row_xpath': '/root/item/contour/entity_spatial/spatials_elements/spatial_element/ordinates/ordinate',
#     'fields': [{'column': 'point_sequence_number', 'rel_xpath': 'ord_nmb'},
#      {'column': 'coordinate_x', 'rel_xpath': 'x'},
#      {'column': 'coordinate_y', 'rel_xpath': 'y'},
#      {'column': 'coordinate_z', 'rel_xpath': 'z'},
#      {'column': 'geopoint_accuracy', 'rel_xpath': 'delta_geopoint'},
#      {'column': 'geopoint_number', 'rel_xpath': 'num_geopoint'},
#      {'column': 'geopoint_determination_code',
#       'rel_xpath': 'geopoint_opred/code'},
#      {'column': 'geopoint_determination_name',
#       'rel_xpath': 'geopoint_opred/value'}]},
#    'parent': {'entity_path': '/root/item/contour/entity_spatial/spatials_elements/spatial_element',
#     'table': 'spatial_element',
#     'fk_column': 'spatial_element_id'},
#    'children': []}],
#  'load_order': ['real_estate_object',
#   'object_contour',
#   'spatial_element',
#   'coordinate_point'],
#  'notes': {'types_origin': 'Types inferred from XML samples and mapped to canonical names.',
#   'decimal_policy': 'decimal(p,s) chosen by max observed integer/fraction digits; scientific notation → float64.',
#   'timestamp_policy': 'ISO-8601 with fractional seconds → timestamp64(ms); without → timestamp.',
#   'nullable_policy': 'nullable=True if field was optional in schema or any NULL/empty observed.',
#   'pk_fk': 'Each table has surrogate PK id (int64); children have FK to parent id.',
#   'order_policy': 'order_by uses observed ordering_hints; if absent, synthetic seq within parent is added.'}}

# %%
final_spec = make_final_profile(entities, patch_json, r"C:\Users\1\CU\data_for_data_engineer\xml\part18.xml")

# %%
final_spec
# Out:
# {'version': 1,
#  'source': {'xml': 'C:\\Users\\1\\CU\\data_for_data_engineer\\xml\\part18.xml'},
#  'typeset': 'canonical',
#  'tables': [{'entity_path': '/root/item',
#    'name': 'item',
#    'alias': 'real_estate_object',
#    'title': 'Объект недвижимости',
#    'description': 'Основная сущность, представляющая объект недвижимости с кадастровыми, техническими и учетными характеристиками.',
#    'table': 'real_estate_object',
#    'columns': [{'name': 'id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'pk_surrogate',
#      'description': 'Суррогатный первичный ключ.'},
#     {'name': 'unverified_purpose_code',
#      'type': 'int64',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/purpose/code',
#      'is_key_hint': False,
#      'observed': {'non_null': 4, 'nulls': 0, 'samples': 4},
#      'title': 'Код назначения (неподтвержденные данные)',
#      'description': 'Код предполагаемого назначения объекта, не прошедший проверку.'},
#     {'name': 'unverified_purpose_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/purpose/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 4, 'nulls': 0, 'samples': 4},
#      'title': 'Назначение (неподтвержденные данные)',
#      'description': 'Наименование предполагаемого назначения объекта, не прошедшее проверку.'},
#     {'name': 'unverified_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/name',
#      'is_key_hint': False,
#      'observed': {'non_null': 19, 'nulls': 0, 'samples': 19},
#      'title': 'Наименование (неподтвержденные данные)',
#      'description': 'Наименование объекта, указанное без подтверждения.'},
#     {'name': 'unverified_area',
#      'type': 'decimal(6,1)',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/area',
#      'is_key_hint': False,
#      'observed': {'non_null': 13, 'nulls': 0, 'samples': 13},
#      'title': 'Площадь (неподтвержденные данные)',
#      'description': 'Площадь объекта по неподтвержденным данным.'},
#     {'name': 'unverified_floors',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/floors',
#      'is_key_hint': False,
#      'observed': {'non_null': 1, 'nulls': 0, 'samples': 1},
#      'title': 'Этажность (неподтвержденные данные)',
#      'description': 'Количество этажей по неподтвержденным данным.'},
#     {'name': 'unverified_underground_floors',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'actual_unverified_data/underground_floors',
#      'is_key_hint': False,
#      'observed': {'non_null': 0, 'nulls': 0, 'samples': 0},
#      'title': 'Подземные этажи (неподтвержденные данные)',
#      'description': 'Количество подземных этажей по неподтвержденным данным.'},
#     {'name': 'inventory_cost',
#      'type': 'decimal(11,2)',
#      'nullable': True,
#      'source_path': 'dated_info/oti/invent_cost',
#      'is_key_hint': False,
#      'observed': {'non_null': 624, 'nulls': 0, 'samples': 624},
#      'title': 'Инвентаризационная стоимость',
#      'description': 'Оценочная стоимость объекта по данным инвентаризации.'},
#     {'name': 'inventory_letter',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'dated_info/oti/letter',
#      'is_key_hint': False,
#      'observed': {'non_null': 785, 'nulls': 0, 'samples': 785},
#      'title': 'Литера по инвентаризации',
#      'description': 'Обозначение литера (буквенного кода) здания по данным инвентаризации.'},
#     {'name': 'inventory_date',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'dated_info/oti/invent_date',
#      'is_key_hint': False,
#      'observed': {'non_null': 0, 'nulls': 0, 'samples': 0},
#      'title': 'Дата инвентаризации',
#      'description': 'Дата последней инвентаризации объекта.'},
#     {'name': 'inventory_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'dated_info/oti/name_oti',
#      'is_key_hint': False,
#      'observed': {'non_null': 0, 'nulls': 0, 'samples': 0},
#      'title': 'Наименование по инвентаризации',
#      'description': 'Наименование объекта согласно данным технической инвентаризации.'},
#     {'name': 'last_change_record_number',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'metadata/last_change_record_number',
#      'is_key_hint': False,
#      'observed': {'non_null': 1997, 'nulls': 3, 'samples': 2000},
#      'title': 'Номер последней записи изменений',
#      'description': 'Идентификатор последней записи изменений объекта в системе.'},
#     {'name': 'last_container_fixed_at',
#      'type': 'timestamp',
#      'nullable': False,
#      'source_path': 'metadata/last_container_fixed_at',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Дата последней фиксации контейнера',
#      'description': 'Дата фиксации последнего состояния объекта в контейнере данных.'},
#     {'name': 'record_status',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'metadata/status',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Статус записи',
#      'description': 'Текущий статус записи объекта недвижимости.'},
#     {'name': 'cadastral_number',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'object_common_data/cad_number',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Кадастровый номер',
#      'description': 'Уникальный кадастровый номер объекта недвижимости.'},
#     {'name': 'was_previously_registered',
#      'type': 'bool',
#      'nullable': True,
#      'source_path': 'object_common_data/previously_posted',
#      'is_key_hint': False,
#      'observed': {'non_null': 1437, 'nulls': 0, 'samples': 1437},
#      'title': 'Ранее учтённый',
#      'description': 'Признак того, что объект был ранее поставлен на учет.'},
#     {'name': 'quarter_cadastral_number',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'object_common_data/quarter_cad_number',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Кадастровый номер квартала',
#      'description': 'Кадастровый номер квартала, в котором расположен объект.'},
#     {'name': 'object_type_code',
#      'type': 'int64',
#      'nullable': False,
#      'source_path': 'object_common_data/type/code',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Код типа объекта',
#      'description': 'Код, обозначающий тип объекта недвижимости.'},
#     {'name': 'object_type_name',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'object_common_data/type/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Тип объекта',
#      'description': 'Наименование типа объекта недвижимости.'},
#     {'name': 'temporary_info',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'object_common_data/temporary_info',
#      'is_key_hint': False,
#      'observed': {'non_null': 0, 'nulls': 0, 'samples': 0},
#      'title': 'Временная информация',
#      'description': 'Дополнительная временная информация об объекте.'},
#     {'name': 'object_definition',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'object_common_data/definition',
#      'is_key_hint': False,
#      'observed': {'non_null': 0, 'nulls': 0, 'samples': 0},
#      'title': 'Описание объекта',
#      'description': 'Описание или определение объекта недвижимости.'},
#     {'name': 'formation_method_code',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'object_formation/method/code',
#      'is_key_hint': False,
#      'observed': {'non_null': 3, 'nulls': 0, 'samples': 3},
#      'title': 'Код метода образования',
#      'description': 'Код способа образования объекта недвижимости.'},
#     {'name': 'formation_method_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'object_formation/method/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 3, 'nulls': 0, 'samples': 3},
#      'title': 'Метод образования',
#      'description': 'Наименование способа образования объекта.'},
#     {'name': 'declared_area',
#      'type': 'decimal(6,1)',
#      'nullable': True,
#      'source_path': 'params/area',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Заявленная площадь',
#      'description': 'Площадь объекта, заявленная пользователем.'},
#     {'name': 'declared_floors',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/floors',
#      'is_key_hint': False,
#      'observed': {'non_null': 1883, 'nulls': 0, 'samples': 1883},
#      'title': 'Заявленная этажность',
#      'description': 'Количество этажей по заявленным данным.'},
#     {'name': 'wall_material_code',
#      'type': 'int64',
#      'nullable': True,
#      'source_path': 'params/material/code',
#      'is_key_hint': False,
#      'observed': {'non_null': 1655, 'nulls': 0, 'samples': 1655},
#      'title': 'Код материала стен',
#      'description': 'Код материала, из которого выполнены стены объекта.'},
#     {'name': 'wall_material_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/material/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 1655, 'nulls': 0, 'samples': 1655},
#      'title': 'Материал стен',
#      'description': 'Наименование материала стен объекта.'},
#     {'name': 'declared_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/name',
#      'is_key_hint': False,
#      'observed': {'non_null': 1777, 'nulls': 0, 'samples': 1777},
#      'title': 'Заявленное наименование',
#      'description': 'Наименование объекта, указанное заявителем.'},
#     {'name': 'permitted_use_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/permitted_use/name',
#      'is_key_hint': False,
#      'observed': {'non_null': 27, 'nulls': 0, 'samples': 27},
#      'title': 'Разрешенное использование',
#      'description': 'Наименование разрешенного использования объекта.'},
#     {'name': 'declared_purpose_code',
#      'type': 'int64',
#      'nullable': True,
#      'source_path': 'params/purpose/code',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Код назначения (заявленное)',
#      'description': 'Код назначения объекта, заявленный пользователем.'},
#     {'name': 'declared_purpose_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/purpose/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Назначение (заявленное)',
#      'description': 'Наименование назначения объекта, заявленное пользователем.'},
#     {'name': 'year_built',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'params/year_built',
#      'is_key_hint': False,
#      'observed': {'non_null': 1425, 'nulls': 0, 'samples': 1425},
#      'title': 'Год постройки',
#      'description': 'Год завершения строительства объекта.'},
#     {'name': 'year_commissioned',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/year_commisioning',
#      'is_key_hint': False,
#      'observed': {'non_null': 635, 'nulls': 0, 'samples': 635},
#      'title': 'Год ввода в эксплуатацию',
#      'description': 'Год ввода объекта в эксплуатацию.'},
#     {'name': 'declared_underground_floors',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'params/underground_floors',
#      'is_key_hint': False,
#      'observed': {'non_null': 463, 'nulls': 0, 'samples': 463},
#      'title': 'Подземные этажи (заявленное)',
#      'description': 'Количество подземных этажей по заявленным данным.'},
#     {'name': 'record_number',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'record_info/record_number',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Номер записи',
#      'description': 'Номер учетной записи объекта в системе.'},
#     {'name': 'registration_date',
#      'type': 'timestamp',
#      'nullable': False,
#      'source_path': 'record_info/registration_date',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Дата регистрации',
#      'description': 'Дата государственной регистрации объекта.'},
#     {'name': 'section_number',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'record_info/section_number',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Номер раздела',
#      'description': 'Номер раздела в реестре, к которому относится объект.'},
#     {'name': 'record_cancel_date',
#      'type': 'timestamp',
#      'nullable': True,
#      'source_path': 'record_info/cancel_date',
#      'is_key_hint': False,
#      'observed': {'non_null': 90, 'nulls': 0, 'samples': 90},
#      'title': 'Дата аннулирования записи',
#      'description': 'Дата аннулирования учетной записи объекта.'}],
#    'primary_key': {'columns': ['id'], 'type': 'surrogate'},
#    'natural_key_candidates': ['cadastral_number',
#     'declared_purpose_code',
#     'record_number',
#     'section_number'],
#    'unique': [{'columns': ['cadastral_number',
#       'declared_purpose_code',
#       'record_number',
#       'section_number'],
#      'note': 'Наблюдаемый естественный ключ (из key_hints).'}],
#    'order_by': [],
#    'extract': {'row_xpath': '/root/item',
#     'fields': [{'column': 'unverified_purpose_code',
#       'rel_xpath': 'actual_unverified_data/purpose/code'},
#      {'column': 'unverified_purpose_name',
#       'rel_xpath': 'actual_unverified_data/purpose/value'},
#      {'column': 'unverified_name', 'rel_xpath': 'actual_unverified_data/name'},
#      {'column': 'unverified_area', 'rel_xpath': 'actual_unverified_data/area'},
#      {'column': 'unverified_floors',
#       'rel_xpath': 'actual_unverified_data/floors'},
#      {'column': 'unverified_underground_floors',
#       'rel_xpath': 'actual_unverified_data/underground_floors'},
#      {'column': 'inventory_cost', 'rel_xpath': 'dated_info/oti/invent_cost'},
#      {'column': 'inventory_letter', 'rel_xpath': 'dated_info/oti/letter'},
#      {'column': 'inventory_date', 'rel_xpath': 'dated_info/oti/invent_date'},
#      {'column': 'inventory_name', 'rel_xpath': 'dated_info/oti/name_oti'},
#      {'column': 'last_change_record_number',
#       'rel_xpath': 'metadata/last_change_record_number'},
#      {'column': 'last_container_fixed_at',
#       'rel_xpath': 'metadata/last_container_fixed_at'},
#      {'column': 'record_status', 'rel_xpath': 'metadata/status'},
#      {'column': 'cadastral_number',
#       'rel_xpath': 'object_common_data/cad_number'},
#      {'column': 'was_previously_registered',
#       'rel_xpath': 'object_common_data/previously_posted'},
#      {'column': 'quarter_cadastral_number',
#       'rel_xpath': 'object_common_data/quarter_cad_number'},
#      {'column': 'object_type_code',
#       'rel_xpath': 'object_common_data/type/code'},
#      {'column': 'object_type_name',
#       'rel_xpath': 'object_common_data/type/value'},
#      {'column': 'temporary_info',
#       'rel_xpath': 'object_common_data/temporary_info'},
#      {'column': 'object_definition',
#       'rel_xpath': 'object_common_data/definition'},
#      {'column': 'formation_method_code',
#       'rel_xpath': 'object_formation/method/code'},
#      {'column': 'formation_method_name',
#       'rel_xpath': 'object_formation/method/value'},
#      {'column': 'declared_area', 'rel_xpath': 'params/area'},
#      {'column': 'declared_floors', 'rel_xpath': 'params/floors'},
#      {'column': 'wall_material_code', 'rel_xpath': 'params/material/code'},
#      {'column': 'wall_material_name', 'rel_xpath': 'params/material/value'},
#      {'column': 'declared_name', 'rel_xpath': 'params/name'},
#      {'column': 'permitted_use_name',
#       'rel_xpath': 'params/permitted_use/name'},
#      {'column': 'declared_purpose_code', 'rel_xpath': 'params/purpose/code'},
#      {'column': 'declared_purpose_name', 'rel_xpath': 'params/purpose/value'},
#      {'column': 'year_built', 'rel_xpath': 'params/year_built'},
#      {'column': 'year_commissioned', 'rel_xpath': 'params/year_commisioning'},
#      {'column': 'declared_underground_floors',
#       'rel_xpath': 'params/underground_floors'},
#      {'column': 'record_number', 'rel_xpath': 'record_info/record_number'},
#      {'column': 'registration_date',
#       'rel_xpath': 'record_info/registration_date'},
#      {'column': 'section_number', 'rel_xpath': 'record_info/section_number'},
#      {'column': 'record_cancel_date',
#       'rel_xpath': 'record_info/cancel_date'}]},
#    'parent': {'entity_path': None, 'table': None, 'fk_column': None},
#    'children': [{'entity_path': '/root/item/contour',
#      'table': 'object_contour',
#      'relpath_from_parent': 'contour',
#      'min': 0,
#      'max': 129}]},
#   {'entity_path': '/root/item/contour',
#    'name': 'contour',
#    'alias': 'object_contour',
#    'title': 'Контур объекта',
#    'description': 'Контур объекта недвижимости, описывающий его пространственное положение и форму.',
#    'table': 'object_contour',
#    'columns': [{'name': 'id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'pk_surrogate',
#      'description': 'Суррогатный первичный ключ.'},
#     {'name': 'real_estate_object_id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'fk_parent',
#      'ref_table': 'real_estate_object',
#      'ref_column': 'id',
#      'description': 'Внешний ключ на родительскую сущность.'},
#     {'name': 'spatial_id',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'entity_spatial/sk_id',
#      'is_key_hint': False,
#      'observed': {'non_null': 1719, 'nulls': 0, 'samples': 1719},
#      'title': 'Идентификатор пространственного элемента',
#      'description': 'Уникальный идентификатор пространственного элемента контура.'},
#     {'name': 'spatial_code',
#      'type': 'decimal(3,1)',
#      'nullable': True,
#      'source_path': 'entity_spatial/sk_code/code',
#      'is_key_hint': True,
#      'observed': {'non_null': 934, 'nulls': 0, 'samples': 934},
#      'title': 'Код пространственного элемента',
#      'description': 'Код, определяющий пространственное положение контура.'},
#     {'name': 'spatial_code_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'entity_spatial/sk_code/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 919, 'nulls': 0, 'samples': 919},
#      'title': 'Наименование пространственного кода',
#      'description': 'Наименование, соответствующее коду пространственного элемента.'},
#     {'name': 'contour_definition',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'definition',
#      'is_key_hint': False,
#      'observed': {'non_null': 825, 'nulls': 0, 'samples': 825},
#      'title': 'Описание контура',
#      'description': 'Текстовое описание границ контура объекта.'},
#     {'name': 'contour_number',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'number_pp',
#      'is_key_hint': True,
#      'observed': {'non_null': 829, 'nulls': 0, 'samples': 829},
#      'title': 'Порядковый номер контура',
#      'description': 'Порядковый номер контура в составе объекта.'}],
#    'primary_key': {'columns': ['id'], 'type': 'surrogate'},
#    'natural_key_candidates': ['contour_number', 'spatial_code'],
#    'unique': [{'columns': ['contour_number', 'spatial_code'],
#      'note': 'Наблюдаемый естественный ключ (из key_hints).'},
#     {'columns': ['real_estate_object_id', 'contour_number'],
#      'note': 'Уникальность дочерних строк в рамках родителя (FK + order_by).'}],
#    'order_by': ['contour_number'],
#    'extract': {'row_xpath': '/root/item/contour',
#     'fields': [{'column': 'spatial_id', 'rel_xpath': 'entity_spatial/sk_id'},
#      {'column': 'spatial_code', 'rel_xpath': 'entity_spatial/sk_code/code'},
#      {'column': 'spatial_code_name',
#       'rel_xpath': 'entity_spatial/sk_code/value'},
#      {'column': 'contour_definition', 'rel_xpath': 'definition'},
#      {'column': 'contour_number', 'rel_xpath': 'number_pp'}]},
#    'parent': {'entity_path': '/root/item',
#     'table': 'real_estate_object',
#     'fk_column': 'real_estate_object_id'},
#    'children': [{'entity_path': '/root/item/contour/entity_spatial/spatials_elements/spatial_element',
#      'table': 'spatial_element',
#      'relpath_from_parent': 'entity_spatial/spatials_elements/spatial_element',
#      'min': 0,
#      'max': 99}]},
#   {'entity_path': '/root/item/contour/entity_spatial/spatials_elements/spatial_element',
#    'name': 'spatial_element',
#    'alias': 'spatial_element',
#    'title': 'Пространственный элемент',
#    'description': 'Пространственный элемент, входящий в состав контура, определяющий его часть на определенном уровне.',
#    'table': 'spatial_element',
#    'columns': [{'name': 'id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'pk_surrogate',
#      'description': 'Суррогатный первичный ключ.'},
#     {'name': 'object_contour_id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'fk_parent',
#      'ref_table': 'object_contour',
#      'ref_column': 'id',
#      'description': 'Внешний ключ на родительскую сущность.'},
#     {'name': 'unit_type_code',
#      'type': 'int32',
#      'nullable': False,
#      'source_path': 'type_unit/code',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Код типа единицы',
#      'description': 'Код, определяющий тип единицы измерения или пространственного элемента.'},
#     {'name': 'unit_type_name',
#      'type': 'string',
#      'nullable': False,
#      'source_path': 'type_unit/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Тип единицы',
#      'description': 'Наименование типа единицы или пространственного элемента.'},
#     {'name': 'contour_level_code',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'level_contour/code',
#      'is_key_hint': True,
#      'observed': {'non_null': 735, 'nulls': 0, 'samples': 735},
#      'title': 'Код уровня контура',
#      'description': 'Код уровня, на котором расположен пространственный элемент.'},
#     {'name': 'contour_level_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'level_contour/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 735, 'nulls': 0, 'samples': 735},
#      'title': 'Уровень контура',
#      'description': 'Наименование уровня расположения пространственного элемента.'},
#     {'name': 'seq',
#      'type': 'int32',
#      'nullable': False,
#      'role': 'sequence_within_parent',
#      'description': 'Порядковый номер строки в рамках родительской записи.'}],
#    'primary_key': {'columns': ['id'], 'type': 'surrogate'},
#    'natural_key_candidates': ['contour_level_code', 'unit_type_code'],
#    'unique': [{'columns': ['contour_level_code', 'unit_type_code'],
#      'note': 'Наблюдаемый естественный ключ (из key_hints).'},
#     {'columns': ['object_contour_id', 'seq'],
#      'note': 'Уникальность дочерних строк в рамках родителя (FK + order_by).'}],
#    'order_by': ['seq'],
#    'extract': {'row_xpath': '/root/item/contour/entity_spatial/spatials_elements/spatial_element',
#     'fields': [{'column': 'unit_type_code', 'rel_xpath': 'type_unit/code'},
#      {'column': 'unit_type_name', 'rel_xpath': 'type_unit/value'},
#      {'column': 'contour_level_code', 'rel_xpath': 'level_contour/code'},
#      {'column': 'contour_level_name', 'rel_xpath': 'level_contour/value'}]},
#    'parent': {'entity_path': '/root/item/contour',
#     'table': 'object_contour',
#     'fk_column': 'object_contour_id'},
#    'children': [{'entity_path': '/root/item/contour/entity_spatial/spatials_elements/spatial_element/ordinates/ordinate',
#      'table': 'coordinate_point',
#      'relpath_from_parent': 'ordinates/ordinate',
#      'min': 0,
#      'max': 922}]},
#   {'entity_path': '/root/item/contour/entity_spatial/spatials_elements/spatial_element/ordinates/ordinate',
#    'name': 'ordinate',
#    'alias': 'coordinate_point',
#    'title': 'Опорная точка (ордината)',
#    'description': 'Координатная точка, определяющая геометрию пространственного элемента.',
#    'table': 'coordinate_point',
#    'columns': [{'name': 'id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'pk_surrogate',
#      'description': 'Суррогатный первичный ключ.'},
#     {'name': 'spatial_element_id',
#      'type': 'int64',
#      'nullable': False,
#      'role': 'fk_parent',
#      'ref_table': 'spatial_element',
#      'ref_column': 'id',
#      'description': 'Внешний ключ на родительскую сущность.'},
#     {'name': 'point_sequence_number',
#      'type': 'int32',
#      'nullable': False,
#      'source_path': 'ord_nmb',
#      'is_key_hint': True,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Порядковый номер точки',
#      'description': 'Порядковый номер координатной точки в описании геометрии.'},
#     {'name': 'coordinate_x',
#      'type': 'decimal(9,2)',
#      'nullable': False,
#      'source_path': 'x',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Координата X',
#      'description': 'Координата X точки в системе координат.'},
#     {'name': 'coordinate_y',
#      'type': 'decimal(8,2)',
#      'nullable': False,
#      'source_path': 'y',
#      'is_key_hint': False,
#      'observed': {'non_null': 2000, 'nulls': 0, 'samples': 2000},
#      'title': 'Координата Y',
#      'description': 'Координата Y точки в системе координат.'},
#     {'name': 'coordinate_z',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'z',
#      'is_key_hint': False,
#      'observed': {'non_null': 654, 'nulls': 0, 'samples': 654},
#      'title': 'Координата Z',
#      'description': 'Координата Z точки (высота), если задана.'},
#     {'name': 'geopoint_accuracy',
#      'type': 'decimal(3,2)',
#      'nullable': True,
#      'source_path': 'delta_geopoint',
#      'is_key_hint': False,
#      'observed': {'non_null': 1130, 'nulls': 0, 'samples': 1130},
#      'title': 'Точность геоточки',
#      'description': 'Допустимое отклонение координаты точки.'},
#     {'name': 'geopoint_number',
#      'type': 'int32',
#      'nullable': True,
#      'source_path': 'num_geopoint',
#      'is_key_hint': True,
#      'observed': {'non_null': 1116, 'nulls': 0, 'samples': 1116},
#      'title': 'Номер геоточки',
#      'description': 'Идентификатор геоточки в пределах пространственного элемента.'},
#     {'name': 'geopoint_determination_code',
#      'type': 'int64',
#      'nullable': True,
#      'source_path': 'geopoint_opred/code',
#      'is_key_hint': True,
#      'observed': {'non_null': 166, 'nulls': 0, 'samples': 166},
#      'title': 'Код способа определения точки',
#      'description': 'Код, обозначающий способ определения координат точки.'},
#     {'name': 'geopoint_determination_name',
#      'type': 'string',
#      'nullable': True,
#      'source_path': 'geopoint_opred/value',
#      'is_key_hint': False,
#      'observed': {'non_null': 166, 'nulls': 0, 'samples': 166},
#      'title': 'Способ определения точки',
#      'description': 'Наименование способа определения координат точки.'}],
#    'primary_key': {'columns': ['id'], 'type': 'surrogate'},
#    'natural_key_candidates': ['geopoint_determination_code',
#     'geopoint_number',
#     'point_sequence_number'],
#    'unique': [{'columns': ['geopoint_determination_code',
#       'geopoint_number',
#       'point_sequence_number'],
#      'note': 'Наблюдаемый естественный ключ (из key_hints).'},
#     {'columns': ['spatial_element_id',
#       'point_sequence_number',
#       'geopoint_number'],
#      'note': 'Уникальность дочерних строк в рамках родителя (FK + order_by).'}],
#    'order_by': ['point_sequence_number', 'geopoint_number'],
#    'extract': {'row_xpath': '/root/item/contour/entity_spatial/spatials_elements/spatial_element/ordinates/ordinate',
#     'fields': [{'column': 'point_sequence_number', 'rel_xpath': 'ord_nmb'},
#      {'column': 'coordinate_x', 'rel_xpath': 'x'},
#      {'column': 'coordinate_y', 'rel_xpath': 'y'},
#      {'column': 'coordinate_z', 'rel_xpath': 'z'},
#      {'column': 'geopoint_accuracy', 'rel_xpath': 'delta_geopoint'},
#      {'column': 'geopoint_number', 'rel_xpath': 'num_geopoint'},
#      {'column': 'geopoint_determination_code',
#       'rel_xpath': 'geopoint_opred/code'},
#      {'column': 'geopoint_determination_name',
#       'rel_xpath': 'geopoint_opred/value'}]},
#    'parent': {'entity_path': '/root/item/contour/entity_spatial/spatials_elements/spatial_element',
#     'table': 'spatial_element',
#     'fk_column': 'spatial_element_id'},
#    'children': []}],
#  'load_order': ['real_estate_object',
#   'object_contour',
#   'spatial_element',
#   'coordinate_point'],
#  'notes': {'types_origin': 'Types inferred from XML samples and mapped to canonical names.',
#   'decimal_policy': 'decimal(p,s) chosen by max observed integer/fraction digits; scientific notation → float64.',
#   'timestamp_policy': 'ISO-8601 with fractional seconds → timestamp64(ms); without → timestamp.',
#   'nullable_policy': 'nullable=True if field was optional in schema or any NULL/empty observed.',
#   'pk_fk': 'Each table has surrogate PK id (int64); children have FK to parent id.',
#   'order_policy': 'order_by uses observed ordering_hints; if absent, synthetic seq within parent is added.'}}

# %% [markdown]
# # DDL

# %%
# final_spec = make_final_profile(entities, patch_json, xml_path)

from ddl_postgres import generate_postgres_ddl
from ddl_clickhouse import generate_clickhouse_ddl

pg_sql = generate_postgres_ddl(final_spec, schema="public")
ch_sql = generate_clickhouse_ddl(final_spec, database="raw")

print(pg_sql)
# Out:
# CREATE SCHEMA IF NOT EXISTS public;
# CREATE TABLE IF NOT EXISTS public.real_estate_object (
#     id bigint NOT NULL,
#     unverified_purpose_code bigint,
#     unverified_purpose_name text,
#     unverified_name text,
#     unverified_area numeric(6,1),
#     unverified_floors integer,
#     unverified_underground_floors text,
#     inventory_cost numeric(11,2),
#     inventory_letter text,
#     inventory_date text,
#     inventory_name text,
#     last_change_record_number text,
#     last_container_fixed_at timestamptz NOT NULL,
#     record_status text NOT NULL,
#     cadastral_number text NOT NULL,
#     was_previously_registered boolean,
#     quarter_cadastral_number text NOT NULL,
#     object_type_code bigint NOT NULL,
#     object_type_name text NOT NULL,
#     temporary_info text,
#     object_definition text,
#     formation_method_code integer,
#     formation_method_name text,
#     declared_area numeric(6,1),
#     declared_floors text,
#     wall_material_code bigint,
#     wall_material_name text,
#     declared_name text,
#     permitted_use_name text,
#     declared_purpose_code bigint,
#     declared_purpose_name text,
#     year_built integer,
#     year_commissioned text,
#     declared_underground_floors text,
#     record_number text NOT NULL,
#     registration_date timestamptz NOT NULL,
#     section_number text NOT NULL,
#     record_cancel_date timestamptz,
#     CONSTRAINT pk_real_estate_object PRIMARY KEY (id),
#     CONSTRAINT uq_real_estate_object_1 UNIQUE (cadastral_number, declared_purpose_code, record_number, section_number)
# );
#
# CREATE TABLE IF NOT EXISTS public.object_contour (
#     id bigint NOT NULL,
#     real_estate_object_id bigint NOT NULL,
#     spatial_id text,
#     spatial_code numeric(3,1),
#     spatial_code_name text,
#     contour_definition text,
#     contour_number integer,
#     CONSTRAINT pk_object_contour PRIMARY KEY (id),
#     CONSTRAINT uq_object_contour_1 UNIQUE (contour_number, spatial_code),
#     CONSTRAINT uq_object_contour_2 UNIQUE (real_estate_object_id, contour_number),
#     CONSTRAINT fk_object_contour_real_estate_object_id FOREIGN KEY (real_estate_object_id) REFERENCES public.real_estate_object(id)
# );
# CREATE INDEX IF NOT EXISTS ix_object_contour_real_estate_object_id ON public.object_contour(real_estate_object_id);
#
# CREATE TABLE IF NOT EXISTS public.spatial_element (
#     id bigint NOT NULL,
#     object_contour_id bigint NOT NULL,
#     unit_type_code integer NOT NULL,
#     unit_type_name text NOT NULL,
#     contour_level_code integer,
#     contour_level_name text,
#     seq integer NOT NULL,
#     CONSTRAINT pk_spatial_element PRIMARY KEY (id),
#     CONSTRAINT uq_spatial_element_1 UNIQUE (contour_level_code, unit_type_code),
#     CONSTRAINT uq_spatial_element_2 UNIQUE (object_contour_id, seq),
#     CONSTRAINT fk_spatial_element_object_contour_id FOREIGN KEY (object_contour_id) REFERENCES public.object_contour(id)
# );
# CREATE INDEX IF NOT EXISTS ix_spatial_element_object_contour_id ON public.spatial_element(object_contour_id);
#
# CREATE TABLE IF NOT EXISTS public.coordinate_point (
#     id bigint NOT NULL,
#     spatial_element_id bigint NOT NULL,
#     point_sequence_number integer NOT NULL,
#     coordinate_x numeric(9,2) NOT NULL,
#     coordinate_y numeric(8,2) NOT NULL,
#     coordinate_z integer,
#     geopoint_accuracy numeric(3,2),
#     geopoint_number integer,
#     geopoint_determination_code bigint,
#     geopoint_determination_name text,
#     CONSTRAINT pk_coordinate_point PRIMARY KEY (id),
#     CONSTRAINT uq_coordinate_point_1 UNIQUE (geopoint_determination_code, geopoint_number, point_sequence_number),
#     CONSTRAINT uq_coordinate_point_2 UNIQUE (spatial_element_id, point_sequence_number, geopoint_number),
#     CONSTRAINT fk_coordinate_point_spatial_element_id FOREIGN KEY (spatial_element_id) REFERENCES public.spatial_element(id)
# );
# CREATE INDEX IF NOT EXISTS ix_coordinate_point_spatial_element_id ON public.coordinate_point(spatial_element_id);

# %%
print(ch_sql)
# Out:
# CREATE DATABASE IF NOT EXISTS raw;
#
# -- Объект недвижимости
# -- Основная сущность, представляющая объект недвижимости с кадастровыми, техническими и учетными характеристиками.
# -- UNIQUE (не применяется в CH): (cadastral_number, declared_purpose_code, record_number, section_number)  -- Наблюдаемый естественный ключ (из key_hints).
# CREATE TABLE IF NOT EXISTS raw.real_estate_object (
#     id Int64,
#     unverified_purpose_code Nullable(Int64),
#     unverified_purpose_name Nullable(String),
#     unverified_name Nullable(String),
#     unverified_area Nullable(Decimal(6,1)),
#     unverified_floors Nullable(Int32),
#     unverified_underground_floors Nullable(String),
#     inventory_cost Nullable(Decimal(11,2)),
#     inventory_letter Nullable(String),
#     inventory_date Nullable(String),
#     inventory_name Nullable(String),
#     last_change_record_number Nullable(String),
#     last_container_fixed_at DateTime('UTC'),
#     record_status String,
#     cadastral_number String,
#     was_previously_registered Nullable(Bool),
#     quarter_cadastral_number String,
#     object_type_code Int64,
#     object_type_name String,
#     temporary_info Nullable(String),
#     object_definition Nullable(String),
#     formation_method_code Nullable(Int32),
#     formation_method_name Nullable(String),
#     declared_area Nullable(Decimal(6,1)),
#     declared_floors Nullable(String),
#     wall_material_code Nullable(Int64),
#     wall_material_name Nullable(String),
#     declared_name Nullable(String),
#     permitted_use_name Nullable(String),
#     declared_purpose_code Nullable(Int64),
#     declared_purpose_name Nullable(String),
#     year_built Nullable(Int32),
#     year_commissioned Nullable(String),
#     declared_underground_floors Nullable(String),
#     record_number String,
#     registration_date DateTime('UTC'),
#     section_number String,
#     record_cancel_date Nullable(DateTime('UTC'))
# ) ENGINE = MergeTree
# ORDER BY (id)
# PRIMARY KEY (id);
#
# -- Контур объекта
# -- Контур объекта недвижимости, описывающий его пространственное положение и форму.
# -- FK (не применяется в CH): real_estate_object_id -> real_estate_object(id)
# -- UNIQUE (не применяется в CH): (contour_number, spatial_code)  -- Наблюдаемый естественный ключ (из key_hints).
# -- UNIQUE (не применяется в CH): (real_estate_object_id, contour_number)  -- Уникальность дочерних строк в рамках родителя (FK + order_by).
# CREATE TABLE IF NOT EXISTS raw.object_contour (
#     id Int64,
#     real_estate_object_id Int64,
#     spatial_id Nullable(String),
#     spatial_code Nullable(Decimal(3,1)),
#     spatial_code_name Nullable(String),
#     contour_definition Nullable(String),
#     contour_number Nullable(Int32)
# ) ENGINE = MergeTree
# ORDER BY (contour_number)
# PRIMARY KEY (contour_number);
#
# -- Пространственный элемент
# -- Пространственный элемент, входящий в состав контура, определяющий его часть на определенном уровне.
# -- FK (не применяется в CH): object_contour_id -> object_contour(id)
# -- UNIQUE (не применяется в CH): (contour_level_code, unit_type_code)  -- Наблюдаемый естественный ключ (из key_hints).
# -- UNIQUE (не применяется в CH): (object_contour_id, seq)  -- Уникальность дочерних строк в рамках родителя (FK + order_by).
# CREATE TABLE IF NOT EXISTS raw.spatial_element (
#     id Int64,
#     object_contour_id Int64,
#     unit_type_code Int32,
#     unit_type_name String,
#     contour_level_code Nullable(Int32),
#     contour_level_name Nullable(String),
#     seq Int32
# ) ENGINE = MergeTree
# ORDER BY (seq)
# PRIMARY KEY (seq);
#
# -- Опорная точка (ордината)
# -- Координатная точка, определяющая геометрию пространственного элемента.
# -- FK (не применяется в CH): spatial_element_id -> spatial_element(id)
# -- UNIQUE (не применяется в CH): (geopoint_determination_code, geopoint_number, point_sequence_number)  -- Наблюдаемый естественный ключ (из key_hints).
# -- UNIQUE (не применяется в CH): (spatial_element_id, point_sequence_number, geopoint_number)  -- Уникальность дочерних строк в рамках родителя (FK + order_by).
# CREATE TABLE IF NOT EXISTS raw.coordinate_point (
#     id Int64,
#     spatial_element_id Int64,
#     point_sequence_number Int32,
#     coordinate_x Decimal(9,2),
#     coordinate_y Decimal(8,2),
#     coordinate_z Nullable(Int32),
#     geopoint_accuracy Nullable(Decimal(3,2)),
#     geopoint_number Nullable(Int32),
#     geopoint_determination_code Nullable(Int64),
#     geopoint_determination_name Nullable(String)
# ) ENGINE = MergeTree
# ORDER BY (point_sequence_number, geopoint_number)
# PRIMARY KEY (point_sequence_number, geopoint_number);

# %%
from ddlgenerator_postgres import generate_postgres_ddl
ddl_pg = generate_postgres_ddl(final_spec, schema="public", emit_unique=False)
print(ddl_pg)

# CH (как раньше; без реальных UNIQUE, только комментарии):
from ddlgenerator_clickhouse import generate_clickhouse_ddl
ddl_ch = generate_clickhouse_ddl(final_spec, database="raw", include_unique_comments=True)
print(ddl_ch)
# Out:
# CREATE SCHEMA IF NOT EXISTS public;
# CREATE TABLE IF NOT EXISTS public.real_estate_object (
#     id bigint NOT NULL,
#     unverified_purpose_code bigint,
#     unverified_purpose_name text,
#     unverified_name text,
#     unverified_area numeric(6,1),
#     unverified_floors integer,
#     unverified_underground_floors text,
#     inventory_cost numeric(11,2),
#     inventory_letter text,
#     inventory_date text,
#     inventory_name text,
#     last_change_record_number text,
#     last_container_fixed_at timestamptz NOT NULL,
#     record_status text NOT NULL,
#     cadastral_number text NOT NULL,
#     was_previously_registered boolean,
#     quarter_cadastral_number text NOT NULL,
#     object_type_code bigint NOT NULL,
#     object_type_name text NOT NULL,
#     temporary_info text,
#     object_definition text,
#     formation_method_code integer,
#     formation_method_name text,
#     declared_area numeric(6,1),
#     declared_floors text,
#     wall_material_code bigint,
#     wall_material_name text,
#     declared_name text,
#     permitted_use_name text,
#     declared_purpose_code bigint,
#     declared_purpose_name text,
#     year_built integer,
#     year_commissioned text,
#     declared_underground_floors text,
#     record_number text NOT NULL,
#     registration_date timestamptz NOT NULL,
#     section_number text NOT NULL,
#     record_cancel_date timestamptz,
# ,
#     CONSTRAINT pk_real_estate_object PRIMARY KEY (id)
# );
# CREATE TABLE IF NOT EXISTS public.object_contour (
#     id bigint NOT NULL,
#     real_estate_object_id bigint NOT NULL,
#     spatial_id text,
#     spatial_code numeric(3,1),
#     spatial_code_name text,
#     contour_definition text,
#     contour_number integer,
# ,
#     CONSTRAINT pk_object_contour PRIMARY KEY (id),
#     CONSTRAINT fk_object_contour_real_estate_object_id FOREIGN KEY (real_estate_object_id) REFERENCES public.real_estate_object(id)
# );
# CREATE INDEX IF NOT EXISTS ix_object_contour_real_estate_object_id ON public.object_contour(real_estate_object_id);
# CREATE TABLE IF NOT EXISTS public.spatial_element (
#     id bigint NOT NULL,
#     object_contour_id bigint NOT NULL,
#     unit_type_code integer NOT NULL,
#     unit_type_name text NOT NULL,
#     contour_level_code integer,
#     contour_level_name text,
#     seq integer NOT NULL,
# ,
#     CONSTRAINT pk_spatial_element PRIMARY KEY (id),
#     CONSTRAINT fk_spatial_element_object_contour_id FOREIGN KEY (object_contour_id) REFERENCES public.object_contour(id)
# );
# CREATE INDEX IF NOT EXISTS ix_spatial_element_object_contour_id ON public.spatial_element(object_contour_id);
# CREATE TABLE IF NOT EXISTS public.coordinate_point (
#     id bigint NOT NULL,
#     spatial_element_id bigint NOT NULL,
#     point_sequence_number integer NOT NULL,
#     coordinate_x numeric(9,2) NOT NULL,
#     coordinate_y numeric(8,2) NOT NULL,
#     coordinate_z integer,
#     geopoint_accuracy numeric(3,2),
#     geopoint_number integer,
#     geopoint_determination_code bigint,
#     geopoint_determination_name text,
# ,
#     CONSTRAINT pk_coordinate_point PRIMARY KEY (id),
#     CONSTRAINT fk_coordinate_point_spatial_element_id FOREIGN KEY (spatial_element_id) REFERENCES public.spatial_element(id)
# );
# CREATE INDEX IF NOT EXISTS ix_coordinate_point_spatial_element_id ON public.coordinate_point(spatial_element_id);
# CREATE DATABASE IF NOT EXISTS raw;
#
# -- real_estate_object
# -- Основная сущность, представляющая объект недвижимости с кадастровыми, техническими и учетными характеристиками.
# -- UNIQUE (не применяется в CH): (cadastral_number, declared_purpose_code, record_number, section_number)  -- Наблюдаемый естественный ключ (из key_hints).
# CREATE TABLE IF NOT EXISTS raw.real_estate_object (
#     id Int64,
#     unverified_purpose_code Nullable(Int64),
#     unverified_purpose_name Nullable(String),
#     unverified_name Nullable(String),
#     unverified_area Nullable(Decimal(6,1)),
#     unverified_floors Nullable(Int32),
#     unverified_underground_floors Nullable(String),
#     inventory_cost Nullable(Decimal(11,2)),
#     inventory_letter Nullable(String),
#     inventory_date Nullable(String),
#     inventory_name Nullable(String),
#     last_change_record_number Nullable(String),
#     last_container_fixed_at DateTime('UTC'),
#     record_status String,
#     cadastral_number String,
#     was_previously_registered Nullable(Bool),
#     quarter_cadastral_number String,
#     object_type_code Int64,
#     object_type_name String,
#     temporary_info Nullable(String),
#     object_definition Nullable(String),
#     formation_method_code Nullable(Int32),
#     formation_method_name Nullable(String),
#     declared_area Nullable(Decimal(6,1)),
#     declared_floors Nullable(String),
#     wall_material_code Nullable(Int64),
#     wall_material_name Nullable(String),
#     declared_name Nullable(String),
#     permitted_use_name Nullable(String),
#     declared_purpose_code Nullable(Int64),
#     declared_purpose_name Nullable(String),
#     year_built Nullable(Int32),
#     year_commissioned Nullable(String),
#     declared_underground_floors Nullable(String),
#     record_number String,
#     registration_date DateTime('UTC'),
#     section_number String,
#     record_cancel_date Nullable(DateTime('UTC'))
# ) ENGINE = MergeTree
# ORDER BY (id)
# PRIMARY KEY (id);
#
# -- object_contour
# -- Контур объекта недвижимости, описывающий его пространственное положение и форму.
# -- UNIQUE (не применяется в CH): (contour_number, spatial_code)  -- Наблюдаемый естественный ключ (из key_hints).
# -- UNIQUE (не применяется в CH): (real_estate_object_id, contour_number)  -- Уникальность дочерних строк в рамках родителя (FK + order_by).
# CREATE TABLE IF NOT EXISTS raw.object_contour (
#     id Int64,
#     real_estate_object_id Int64,
#     spatial_id Nullable(String),
#     spatial_code Nullable(Decimal(3,1)),
#     spatial_code_name Nullable(String),
#     contour_definition Nullable(String),
#     contour_number Nullable(Int32)
# ) ENGINE = MergeTree
# ORDER BY (contour_number)
# PRIMARY KEY (contour_number);
#
# -- spatial_element
# -- Пространственный элемент, входящий в состав контура, определяющий его часть на определенном уровне.
# -- UNIQUE (не применяется в CH): (contour_level_code, unit_type_code)  -- Наблюдаемый естественный ключ (из key_hints).
# -- UNIQUE (не применяется в CH): (object_contour_id, seq)  -- Уникальность дочерних строк в рамках родителя (FK + order_by).
# CREATE TABLE IF NOT EXISTS raw.spatial_element (
#     id Int64,
#     object_contour_id Int64,
#     unit_type_code Int32,
#     unit_type_name String,
#     contour_level_code Nullable(Int32),
#     contour_level_name Nullable(String),
#     seq Int32
# ) ENGINE = MergeTree
# ORDER BY (seq)
# PRIMARY KEY (seq);
#
# -- coordinate_point
# -- Координатная точка, определяющая геометрию пространственного элемента.
# -- UNIQUE (не применяется в CH): (geopoint_determination_code, geopoint_number, point_sequence_number)  -- Наблюдаемый естественный ключ (из key_hints).
# -- UNIQUE (не применяется в CH): (spatial_element_id, point_sequence_number, geopoint_number)  -- Уникальность дочерних строк в рамках родителя (FK + order_by).
# CREATE TABLE IF NOT EXISTS raw.coordinate_point (
#     id Int64,
#     spatial_element_id Int64,
#     point_sequence_number Int32,
#     coordinate_x Decimal(9,2),
#     coordinate_y Decimal(8,2),
#     coordinate_z Nullable(Int32),
#     geopoint_accuracy Nullable(Decimal(3,2)),
#     geopoint_number Nullable(Int32),
#     geopoint_determination_code Nullable(Int64),
#     geopoint_determination_name Nullable(String)
# ) ENGINE = MergeTree
# ORDER BY (point_sequence_number, geopoint_number)
# PRIMARY KEY (point_sequence_number, geopoint_number);

# %% [markdown]
# # DBML

# %%
from dbml_minimal import generate_dbml_minimal

# final_spec — твой объект профиля (dict)
dbml = generate_dbml_minimal(final_spec, with_project=False)
print(dbml)
# Out:
# Table real_estate_object {
#   id bigint [not null, pk]
#   unverified_purpose_code bigint
#   unverified_purpose_name text
#   unverified_name text
#   unverified_area decimal(6,1)
#   unverified_floors int
#   unverified_underground_floors text
#   inventory_cost decimal(11,2)
#   inventory_letter text
#   inventory_date text
#   inventory_name text
#   last_change_record_number text
#   last_container_fixed_at timestamp [not null]
#   record_status text [not null]
#   cadastral_number text [not null]
#   was_previously_registered boolean
#   quarter_cadastral_number text [not null]
#   object_type_code bigint [not null]
#   object_type_name text [not null]
#   temporary_info text
#   object_definition text
#   formation_method_code int
#   formation_method_name text
#   declared_area decimal(6,1)
#   declared_floors text
#   wall_material_code bigint
#   wall_material_name text
#   declared_name text
#   permitted_use_name text
#   declared_purpose_code bigint
#   declared_purpose_name text
#   year_built int
#   year_commissioned text
#   declared_underground_floors text
#   record_number text [not null]
#   registration_date timestamp [not null]
#   section_number text [not null]
#   record_cancel_date timestamp
# }
#
# Table object_contour {
#   id bigint [not null, pk]
#   real_estate_object_id bigint [not null]
#   spatial_id text
#   spatial_code decimal(3,1)
#   spatial_code_name text
#   contour_definition text
#   contour_number int
# }
#
# Table spatial_element {
#   id bigint [not null, pk]
#   object_contour_id bigint [not null]
#   unit_type_code int [not null]
#   unit_type_name text [not null]
#   contour_level_code int
#   contour_level_name text
#   seq int [not null]
# }
#
# Table coordinate_point {
#   id bigint [not null, pk]
#   spatial_element_id bigint [not null]
#   point_sequence_number int [not null]
#   coordinate_x decimal(9,2) [not null]
#   coordinate_y decimal(8,2) [not null]
#   coordinate_z int
#   geopoint_accuracy decimal(3,2)
#   geopoint_number int
#   geopoint_determination_code bigint
#   geopoint_determination_name text
# }
#
# Ref: object_contour.real_estate_object_id > real_estate_object.id
# Ref: spatial_element.object_contour_id > object_contour.id
# Ref: coordinate_point.spatial_element_id > spatial_element.id

# %%
print(dbml_str)
# Out:
# Project 'Registry ETL' {
#   database_type: 'generic'
#   note: 'Generated from final_spec'
# }
#
# Table real_estate_object {
#   id bigint [not null, note: 'Суррогатный первичный ключ.', pk]
#   unverified_purpose_code bigint [note: 'Код назначения (неподтвержденные данные)
# Код предполагаемого назначения объекта, не прошедший проверку.']
#   unverified_purpose_name text [note: 'Назначение (неподтвержденные данные)
# Наименование предполагаемого назначения объекта, не прошедшее проверку.']
#   unverified_name text [note: 'Наименование (неподтвержденные данные)
# Наименование объекта, указанное без подтверждения.']
#   unverified_area decimal(6,1) [note: 'Площадь (неподтвержденные данные)
# Площадь объекта по неподтвержденным данным.']
#   unverified_floors int [note: 'Этажность (неподтвержденные данные)
# Количество этажей по неподтвержденным данным.']
#   unverified_underground_floors text [note: 'Подземные этажи (неподтвержденные данные)
# Количество подземных этажей по неподтвержденным данным.']
#   inventory_cost decimal(11,2) [note: 'Инвентаризационная стоимость
# Оценочная стоимость объекта по данным инвентаризации.']
#   inventory_letter text [note: 'Литера по инвентаризации
# Обозначение литера (буквенного кода) здания по данным инвентаризации.']
#   inventory_date text [note: 'Дата инвентаризации
# Дата последней инвентаризации объекта.']
#   inventory_name text [note: 'Наименование по инвентаризации
# Наименование объекта согласно данным технической инвентаризации.']
#   last_change_record_number text [note: 'Номер последней записи изменений
# Идентификатор последней записи изменений объекта в системе.']
#   last_container_fixed_at timestamp [not null, note: 'Дата последней фиксации контейнера
# Дата фиксации последнего состояния объекта в контейнере данных.']
#   record_status text [not null, note: 'Статус записи
# Текущий статус записи объекта недвижимости.']
#   cadastral_number text [not null, note: 'Кадастровый номер
# Уникальный кадастровый номер объекта недвижимости.']
#   was_previously_registered boolean [note: 'Ранее учтённый
# Признак того, что объект был ранее поставлен на учет.']
#   quarter_cadastral_number text [not null, note: 'Кадастровый номер квартала
# Кадастровый номер квартала, в котором расположен объект.']
#   object_type_code bigint [not null, note: 'Код типа объекта
# Код, обозначающий тип объекта недвижимости.']
#   object_type_name text [not null, note: 'Тип объекта
# Наименование типа объекта недвижимости.']
#   temporary_info text [note: 'Временная информация
# Дополнительная временная информация об объекте.']
#   object_definition text [note: 'Описание объекта
# Описание или определение объекта недвижимости.']
#   formation_method_code int [note: 'Код метода образования
# Код способа образования объекта недвижимости.']
#   formation_method_name text [note: 'Метод образования
# Наименование способа образования объекта.']
#   declared_area decimal(6,1) [note: 'Заявленная площадь
# Площадь объекта, заявленная пользователем.']
#   declared_floors text [note: 'Заявленная этажность
# Количество этажей по заявленным данным.']
#   wall_material_code bigint [note: 'Код материала стен
# Код материала, из которого выполнены стены объекта.']
#   wall_material_name text [note: 'Материал стен
# Наименование материала стен объекта.']
#   declared_name text [note: 'Заявленное наименование
# Наименование объекта, указанное заявителем.']
#   permitted_use_name text [note: 'Разрешенное использование
# Наименование разрешенного использования объекта.']
#   declared_purpose_code bigint [note: 'Код назначения (заявленное)
# Код назначения объекта, заявленный пользователем.']
#   declared_purpose_name text [note: 'Назначение (заявленное)
# Наименование назначения объекта, заявленное пользователем.']
#   year_built int [note: 'Год постройки
# Год завершения строительства объекта.']
#   year_commissioned text [note: 'Год ввода в эксплуатацию
# Год ввода объекта в эксплуатацию.']
#   declared_underground_floors text [note: 'Подземные этажи (заявленное)
# Количество подземных этажей по заявленным данным.']
#   record_number text [not null, note: 'Номер записи
# Номер учетной записи объекта в системе.']
#   registration_date timestamp [not null, note: 'Дата регистрации
# Дата государственной регистрации объекта.']
#   section_number text [not null, note: 'Номер раздела
# Номер раздела в реестре, к которому относится объект.']
#   record_cancel_date timestamp [note: 'Дата аннулирования записи
# Дата аннулирования учетной записи объекта.']
#   note: 'Объект недвижимости
# Основная сущность, представляющая объект недвижимости с кадастровыми, техническими и учетными характеристиками.'
# }
#
# Table object_contour {
#   id bigint [not null, note: 'Суррогатный первичный ключ.', pk]
#   real_estate_object_id bigint [not null, note: 'Внешний ключ на родительскую сущность.']
#   spatial_id text [note: 'Идентификатор пространственного элемента
# Уникальный идентификатор пространственного элемента контура.']
#   spatial_code decimal(3,1) [note: 'Код пространственного элемента
# Код, определяющий пространственное положение контура.']
#   spatial_code_name text [note: 'Наименование пространственного кода
# Наименование, соответствующее коду пространственного элемента.']
#   contour_definition text [note: 'Описание контура
# Текстовое описание границ контура объекта.']
#   contour_number int [note: 'Порядковый номер контура
# Порядковый номер контура в составе объекта.']
#   note: 'Контур объекта
# Контур объекта недвижимости, описывающий его пространственное положение и форму.'
#   indexes {
#   (real_estate_object_id) [name: 'ix_object_contour_real_estate_object_id']
#   }
# }
#
# Table spatial_element {
#   id bigint [not null, note: 'Суррогатный первичный ключ.', pk]
#   object_contour_id bigint [not null, note: 'Внешний ключ на родительскую сущность.']
#   unit_type_code int [not null, note: 'Код типа единицы
# Код, определяющий тип единицы измерения или пространственного элемента.']
#   unit_type_name text [not null, note: 'Тип единицы
# Наименование типа единицы или пространственного элемента.']
#   contour_level_code int [note: 'Код уровня контура
# Код уровня, на котором расположен пространственный элемент.']
#   contour_level_name text [note: 'Уровень контура
# Наименование уровня расположения пространственного элемента.']
#   seq int [not null, note: 'Порядковый номер строки в рамках родительской записи.']
#   note: 'Пространственный элемент
# Пространственный элемент, входящий в состав контура, определяющий его часть на определенном уровне.'
#   indexes {
#   (object_contour_id) [name: 'ix_spatial_element_object_contour_id']
#   }
# }
#
# Table coordinate_point {
#   id bigint [not null, note: 'Суррогатный первичный ключ.', pk]
#   spatial_element_id bigint [not null, note: 'Внешний ключ на родительскую сущность.']
#   point_sequence_number int [not null, note: 'Порядковый номер точки
# Порядковый номер координатной точки в описании геометрии.']
#   coordinate_x decimal(9,2) [not null, note: 'Координата X
# Координата X точки в системе координат.']
#   coordinate_y decimal(8,2) [not null, note: 'Координата Y
# Координата Y точки в системе координат.']
#   coordinate_z int [note: 'Координата Z
# Координата Z точки (высота), если задана.']
#   geopoint_accuracy decimal(3,2) [note: 'Точность геоточки
# Допустимое отклонение координаты точки.']
#   geopoint_number int [note: 'Номер геоточки
# Идентификатор геоточки в пределах пространственного элемента.']
#   geopoint_determination_code bigint [note: 'Код способа определения точки
# Код, обозначающий способ определения координат точки.']
#   geopoint_determination_name text [note: 'Способ определения точки
# Наименование способа определения координат точки.']
#   note: 'Опорная точка (ордината)
# Координатная точка, определяющая геометрию пространственного элемента.'
#   indexes {
#   (spatial_element_id) [name: 'ix_coordinate_point_spatial_element_id']
#   }
# }
#
# Ref: object_contour.real_estate_object_id > real_estate_object.id
# Ref: spatial_element.object_contour_id > object_contour.id
# Ref: coordinate_point.spatial_element_id > spatial_element.id
